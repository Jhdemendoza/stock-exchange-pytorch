# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

from scipy import optimize

import tensorflow as tf
import torch
import os
os.chdir('..')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import datetime
import matplotlib as mpl
from matplotlib import cm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline, FeatureUnion

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
def train_df_test_df(ticker):
    
    def concat_and_return_csvs(original_df, ticker_files):
        for item in ticker_files[1:]:
            this_df = pd.read_csv(data_path+item)
            original_df = pd.concat([original_df, this_df])
        return original_df
    
    data_path = 'data/daily_data/'
    ticker_files = [item for item in os.listdir(data_path) if ticker in item.split('_')]
    ticker_files.sort()
    
    split_idx = int(len(ticker_files) * 0.8)
    train_ticker_files, test_ticker_files = ticker_files[:split_idx], ticker_files[split_idx:]

    train_df = pd.read_csv(data_path+train_ticker_files[0])
    train_df = concat_and_return_csvs(train_df, train_ticker_files)
    
    test_df = pd.read_csv(data_path+test_ticker_files[0])
    test_df = concat_and_return_csvs(test_df, test_ticker_files)
    
    return train_df, test_df

# %%
def get_processed_minute_data(df):
    cols = df.columns.tolist()
    cols_to_drop = cols[:4] + ['label', 'changeOverTime', 'close', 'high', 
                               'low', 'marketAverage', 'marketClose', 
                               'marketOpen', 'volume', 'numberOfTrades', 
                               'notional', 'open', 'marketChangeOverTime']
    df.drop(cols_to_drop, axis=1, inplace=True)
    # necessary
    df.reset_index(drop=True, inplace=True)
    
    idx_to_drop = df.index[df.marketNotional == 0.0]
    df.drop(idx_to_drop, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    df.date = df.date.map(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))
    df['weekday'] = df.date.map(lambda x: str(x.weekday()))
    df['month']   = df.date.map(lambda x: str(x.month))
    
    df.minute = df.minute.map(lambda x: datetime.datetime.strptime(x, '%H:%M'))
    df['hour'] = df.minute.map(lambda x: str(x.hour))
    
    return df

# %%
def get_numeric_categoric(df):
    numeric_cols, categorical_cols = [], []

    for col in df:
        if np.issubdtype(df[col].dtype, np.number):
            numeric_cols += [col]
        else:
            categorical_cols += [col]
    
    return numeric_cols, categorical_cols

# %%
def delta_dataframe(df, numeric_columns):
    '''
    log numerical columns, then return deltas
    '''
    
    MAX_SHIFT_BACWARD, MAX_SHIFT_FORWARD = -20, 20
    added_columns = []
    for shift in [MAX_SHIFT_BACWARD, -10, -5, 3, 5, 10, MAX_SHIFT_FORWARD]:
        for col in numeric_columns:
            new_col_name = col + '_' + str(shift)
            df[new_col_name] = df[col].shift(shift)
            added_columns += [new_col_name]

    df[numeric_columns+added_columns] = df[numeric_columns+added_columns].apply(np.log)
    
    # for lookbacks
    for new_col in added_columns:
        original_col, added_part = new_col.split('_')
        df[new_col] = df[new_col] - df[original_col] if '-' in added_part else \
                      df[original_col] - df[new_col]

    # for today
    # This line is necessary
    temp = df[numeric_columns] - df[numeric_columns].shift(1)
    df[numeric_columns] = temp
    
    assert (df.index == np.arange(len(df))).all()
    df.drop(df.index[list(range(MAX_SHIFT_FORWARD))], axis=0, inplace=True)
    df.reset_index(drop=True, inplace=True)
    #                            negative max_shift_back...
    df.drop(index=list(range(len(df)+MAX_SHIFT_BACWARD, len(df))), inplace=True)
    
    return df

# %%
def load_dataframes(ticker):
    train_df, test_df = train_df_test_df(ticker)
    
#     train_df, test_df = list(map(lambda x: get_processed_minute_data(x), 
#                                  (train_df, test_df)))
    train_df = get_processed_minute_data(train_df)
    test_df  = get_processed_minute_data(test_df)
    
    numeric_cols, categoric_cols = get_numeric_categoric(train_df)
    # This is for the time being...
    categoric_cols = ['weekday', 'month', 'hour']
    
    train_df = delta_dataframe(train_df, numeric_cols)
    test_df  = delta_dataframe(test_df,  numeric_cols)
    
    # Re-evaluate column names from the deltas
    numeric_cols, _ = get_numeric_categoric(train_df)
    
    return train_df, test_df, numeric_cols, categoric_cols

def get_y_cols(numeric_cols):
    price_cols      = [item for item in numeric_cols if '-' in item]
    interested_cols = [item for item in price_cols if 'High' in item or 'Low' in item]
    not_interested_cols = list(set(price_cols) - set(interested_cols))
    return interested_cols, not_interested_cols

# messy code... 
train_df_original, test_df_original, numeric_cols, categoric_cols = load_dataframes('cmg')
y_cols, not_interested = get_y_cols(numeric_cols)
numeric_cols = list(set(numeric_cols) - set(y_cols) - set(not_interested))

# %%
train_df, y_train = train_df_original[numeric_cols], train_df_original[y_cols]
test_df, y_test   = test_df_original[numeric_cols], test_df_original[y_cols]
y_train.drop(y_train.columns[-1:], axis=1, inplace=True)
y_test.drop( y_test.columns[-1:], axis=1, inplace=True)
binary_y_train = (y_train>0.002).astype(np.int)
binary_y_test  = (y_test >0.002 ).astype(np.int)

# %%
# Use only the ones worked well in autoencoder
transfomer = [
    ('Data after min-max scaling',
        MinMaxScaler()),
    ('Data after max-abs scaling',
        MaxAbsScaler()),
    ('Data after quantile transformation (uniform pdf)',
        QuantileTransformer(output_distribution='uniform')),
    ('Data after sample-wise L2 normalizing',
        Normalizer()),
]

combined = FeatureUnion(transfomer)
combined_fit = combined.fit(train_df)

# %%
x_train_transformed = combined.transform(train_df)
x_test_transformed = combined.transform(test_df)

# %%
x_train_transformed.shape, x_test_transformed.shape
# Out:
# ((8849, 100), (2272, 100))

# %%
class LogisticRegressor(nn.Module):
    def __init__(self, input_size, final_output_size):
        super(LogisticRegressor, self).__init__()

        self.l1 = nn.Linear(input_size, 64)
        self.l2 = nn.Linear(64, 32)
        self.l3 = nn.Linear(32, 16)
        self.l4 = nn.Linear(16, final_output_size)

    def forward(self, x):
        x = torch.relu(self.l1(x))
        x = torch.tanh(self.l2(x))
        x = torch.tanh(self.l3(x))
        return torch.sigmoid(self.l4(x))

# %%
class TickerDataSimple(Dataset):
    def __init__(self, ticker, x, y):
        '''
        :param ticker: string
        :param x: np.array of x
        :param y: np.array of y
        '''
        self.ticker = ticker
        self.x = torch.FloatTensor(x)
        self.y = torch.FloatTensor(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, index):
        x = self.x[index]
        y = self.y[index]
        return x, y

# %%
x_train_transformed = combined.transform(train_df)
x_test_transformed = combined.transform(test_df)

spy_dataset = TickerDataSimple('spy', x_train_transformed, 
                               torch.from_numpy(binary_y_train.values).float())

BATCH_SIZE = 64
train_dl = DataLoader(spy_dataset, 
                      num_workers=1, 
                      batch_size=BATCH_SIZE)

spy_testset = TickerDataSimple('spy', x_test_transformed, 
                               torch.from_numpy(binary_y_test.values).float())

BATCH_SIZE = 64
test_dl = DataLoader(spy_testset, 
                      num_workers=1, 
                      batch_size=BATCH_SIZE)

# %%
iter_train_dl = iter(train_dl)

# %%
x, y = next(iter_train_dl)
x.shape, y.shape
# Out:
# (torch.Size([64, 100]), torch.Size([64, 5]))

# %%
class CustomLoss(torch.nn.Module):
    '''
    Implement Focal Loss
    '''
    def __init__(self):
        super(CustomLoss,self).__init__()
        
    def forward(self, y_pred, y_target):
        y_pred = y_pred.flatten()
        y_target = y_target.flatten()
        
        def log_p(pred, target):
            return -((1-pred) * torch.log2(pred) * target)
        
        return (log_p(y_pred, y_target) + log_p(1-y_pred, 1-y_target)).mean()

# %%
from torch.nn.utils import clip_grad_norm_
import torch.optim as optim

# Each Data Points are 24 (6 * 4)
# Transformer has 4 different ways
model = LogisticRegressor(x_train_transformed.shape[1], y_train.shape[1])

criterion = CustomLoss()
# criterion = torch.nn.BCELoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=5e-3, weight_decay=1e-6)

# %%
import ignite
from ignite.metrics import BinaryAccuracy, Loss, Precision, Recall
from ignite.engine import Events, \
                          create_supervised_trainer, \
                          create_supervised_evaluator

# %%
import sklearn.metrics as sk_metrics
import torch.nn.functional as F

# %%
# iter_train_dl = iter(train_dl)

# %%
# x, y = next(iter_train_dl)
# _out = model(x)
# _out = _out.flatten()
# y    = y.flatten()
# _zero_one = _out > 0.5
# print('f1_score: {}'.format(sk_metrics.f1_score(_zero_one.detach().numpy(), y)))
# print('accuracy_score: {}'.format(sk_metrics.accuracy_score(_zero_one, y)))
# print('roc_auc_score: {}'.format(sk_metrics.roc_auc_score(y, _out.detach().numpy())))

# %%
from ignite.metrics import Accuracy
from functools import partial
from sklearn.metrics import roc_auc_score
from ignite.metrics import EpochMetric


def sk_metric_fn(y_preds, y_targets, sk_metrics, activation=None):
    y_true = y_targets.flatten().numpy()
    y_pred = y_preds.flatten().numpy()
    if activation is not None:
        y_preds = activation(y_preds)
    
    return sk_metrics(y_true, y_pred)

class ROC_AUC(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(ROC_AUC, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.roc_auc_score, 
                    activation=activation),
            output_transform=output_transform)

class F1_Score(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(F1_Score, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.f1_score, 
                    activation=activation),
            output_transform=output_transform)

class BinaryAccuracy(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(BinaryAccuracy, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.accuracy_score, 
                    activation=activation),
            output_transform=output_transform)

class Precision(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(Precision, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.precision_score, 
                    activation=activation),
            output_transform=output_transform)

class Recall(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(Recall, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.recall_score, 
                    activation=activation),
            output_transform=output_transform)

# %%
def zero_one(y_preds):
    return y_preds > 0.5
    
def zero_one_transform(output):
    return (zero_one(output[0])).long(), output[1].long()

# %%
bce_loss = nn.modules.loss.BCELoss()

trainer = create_supervised_trainer(model, optimizer, criterion)
evaluator = create_supervised_evaluator(
    model,
    metrics={
        'accuracy' : BinaryAccuracy(output_transform=zero_one_transform),
        'bce':       Loss(bce_loss),
        'f1_score' : F1_Score(output_transform=zero_one_transform),
        'roc_auc'  : ROC_AUC(),
        'precision': Precision(output_transform=zero_one_transform),
        'recall'   : Recall(output_transform=zero_one_transform),
    })

# %%
@trainer.on(Events.EPOCH_COMPLETED)
def log_training_results(trainer):
    evaluator.run(train_dl)
    metrics = evaluator.state.metrics
    print("Training Results  - Epoch: {} Avg accuracy: {:.5f}, Avg BCE: {:.5f}, F1 Score: {:.5f}, ROC_AUC: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['accuracy'], 
                  metrics['bce'],
                  metrics['f1_score'],
                  metrics['roc_auc'],
                 ))
    print("Training Results  - Epoch: {} Precision: {:.5f}, Recall: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['precision'], 
                  metrics['recall'],
                 ))

@trainer.on(Events.EPOCH_COMPLETED)
def log_validation_results(trainer):
    evaluator.run(test_dl)
    metrics = evaluator.state.metrics
    print("Validation Results- Epoch: {} Avg accuracy: {:.5f}, Avg BCE: {:.5f}, F1 Score: {:.5f}, ROC_AUC: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['accuracy'], 
                  metrics['bce'],
                  metrics['f1_score'],
                  metrics['roc_auc'],
                 ))
    print("Validation Results- Epoch: {} Precision: {:.5f}, Recall: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['precision'],
                  metrics['recall'],
                 ))

# %%
trainer.run(train_dl, max_epochs=80)
# Out:
# Training Results  - Epoch: 1 Avg accuracy: 0.77848, Avg BCE: 0.51318, F1 Score: 0.19060, ROC_AUC: 0.69108
# Training Results  - Epoch: 1 Precision: 0.70237, Recall: 0.11026
# Validation Results- Epoch: 1 Avg accuracy: 0.77148, Avg BCE: 0.53848, F1 Score: 0.06619, ROC_AUC: 0.57226
# Validation Results- Epoch: 1 Precision: 0.24798, Recall: 0.03819
# Training Results  - Epoch: 2 Avg accuracy: 0.77749, Avg BCE: 0.51297, F1 Score: 0.18251, ROC_AUC: 0.69319
# Training Results  - Epoch: 2 Precision: 0.69689, Recall: 0.10501
# Validation Results- Epoch: 2 Avg accuracy: 0.77306, Avg BCE: 0.53870, F1 Score: 0.06255, ROC_AUC: 0.57010
# Validation Results- Epoch: 2 Precision: 0.25220, Recall: 0.03570
# Training Results  - Epoch: 3 Avg accuracy: 0.77613, Avg BCE: 0.51663, F1 Score: 0.18093, ROC_AUC: 0.68304
# Training Results  - Epoch: 3 Precision: 0.67240, Recall: 0.10453
# Validation Results- Epoch: 3 Avg accuracy: 0.77104, Avg BCE: 0.54225, F1 Score: 0.06674, ROC_AUC: 0.56105
# Validation Results- Epoch: 3 Precision: 0.24603, Recall: 0.03861
# Training Results  - Epoch: 4 Avg accuracy: 0.77677, Avg BCE: 0.51513, F1 Score: 0.18257, ROC_AUC: 0.68547
# Training Results  - Epoch: 4 Precision: 0.68213, Recall: 0.10539
# Validation Results- Epoch: 4 Avg accuracy: 0.77148, Avg BCE: 0.54082, F1 Score: 0.06820, ROC_AUC: 0.56230
# Validation Results- Epoch: 4 Precision: 0.25199, Recall: 0.03944
# Training Results  - Epoch: 5 Avg accuracy: 0.77767, Avg BCE: 0.51398, F1 Score: 0.18291, ROC_AUC: 0.68633
# Training Results  - Epoch: 5 Precision: 0.69994, Recall: 0.10520
# Validation Results- Epoch: 5 Avg accuracy: 0.77298, Avg BCE: 0.53889, F1 Score: 0.06996, ROC_AUC: 0.57322
# Validation Results- Epoch: 5 Precision: 0.26648, Recall: 0.04027
# Training Results  - Epoch: 6 Avg accuracy: 0.77631, Avg BCE: 0.51722, F1 Score: 0.18550, ROC_AUC: 0.68233
# Training Results  - Epoch: 6 Precision: 0.66884, Recall: 0.10768
# Validation Results- Epoch: 6 Avg accuracy: 0.77183, Avg BCE: 0.54032, F1 Score: 0.06695, ROC_AUC: 0.57351
# Validation Results- Epoch: 6 Precision: 0.25203, Recall: 0.03861
# Training Results  - Epoch: 7 Avg accuracy: 0.77998, Avg BCE: 0.51176, F1 Score: 0.20459, ROC_AUC: 0.69074
# Training Results  - Epoch: 7 Precision: 0.70615, Recall: 0.11963
# Validation Results- Epoch: 7 Avg accuracy: 0.77271, Avg BCE: 0.53964, F1 Score: 0.07588, ROC_AUC: 0.56875
# Validation Results- Epoch: 7 Precision: 0.27532, Recall: 0.04400
# Training Results  - Epoch: 8 Avg accuracy: 0.77801, Avg BCE: 0.51418, F1 Score: 0.20354, ROC_AUC: 0.68711
# Training Results  - Epoch: 8 Precision: 0.67256, Recall: 0.11991
# Validation Results- Epoch: 8 Avg accuracy: 0.77227, Avg BCE: 0.53996, F1 Score: 0.07969, ROC_AUC: 0.57343
# Validation Results- Epoch: 8 Precision: 0.27861, Recall: 0.04649
# Training Results  - Epoch: 9 Avg accuracy: 0.77812, Avg BCE: 0.51398, F1 Score: 0.19075, ROC_AUC: 0.68763
# Training Results  - Epoch: 9 Precision: 0.69489, Recall: 0.11055
# Validation Results- Epoch: 9 Avg accuracy: 0.77377, Avg BCE: 0.53752, F1 Score: 0.07354, ROC_AUC: 0.57827
# Validation Results- Epoch: 9 Precision: 0.27945, Recall: 0.04234
# Training Results  - Epoch: 10 Avg accuracy: 0.77803, Avg BCE: 0.51320, F1 Score: 0.18882, ROC_AUC: 0.68909
# Training Results  - Epoch: 10 Precision: 0.69653, Recall: 0.10921
# Validation Results- Epoch: 10 Avg accuracy: 0.77368, Avg BCE: 0.53828, F1 Score: 0.06814, ROC_AUC: 0.57156
# Validation Results- Epoch: 10 Precision: 0.26857, Recall: 0.03902
# Training Results  - Epoch: 11 Avg accuracy: 0.77964, Avg BCE: 0.51173, F1 Score: 0.21091, ROC_AUC: 0.69486
# Training Results  - Epoch: 11 Precision: 0.68942, Recall: 0.12450
# Validation Results- Epoch: 11 Avg accuracy: 0.77350, Avg BCE: 0.54054, F1 Score: 0.08009, ROC_AUC: 0.57335
# Validation Results- Epoch: 11 Precision: 0.28866, Recall: 0.04649
# Training Results  - Epoch: 12 Avg accuracy: 0.77708, Avg BCE: 0.51344, F1 Score: 0.19030, ROC_AUC: 0.69041
# Training Results  - Epoch: 12 Precision: 0.67580, Recall: 0.11074
# Validation Results- Epoch: 12 Avg accuracy: 0.77324, Avg BCE: 0.53828, F1 Score: 0.06667, ROC_AUC: 0.57313
# Validation Results- Epoch: 12 Precision: 0.26211, Recall: 0.03819
# Training Results  - Epoch: 13 Avg accuracy: 0.77873, Avg BCE: 0.51287, F1 Score: 0.20303, ROC_AUC: 0.68909
# Training Results  - Epoch: 13 Precision: 0.68592, Recall: 0.11915
# Validation Results- Epoch: 13 Avg accuracy: 0.77113, Avg BCE: 0.54042, F1 Score: 0.07539, ROC_AUC: 0.57094
# Validation Results- Epoch: 13 Precision: 0.26303, Recall: 0.04400
# Training Results  - Epoch: 14 Avg accuracy: 0.77932, Avg BCE: 0.51385, F1 Score: 0.19319, ROC_AUC: 0.69074
# Training Results  - Epoch: 14 Precision: 0.71455, Recall: 0.11170
# Validation Results- Epoch: 14 Avg accuracy: 0.77333, Avg BCE: 0.54008, F1 Score: 0.07207, ROC_AUC: 0.57323
# Validation Results- Epoch: 14 Precision: 0.27322, Recall: 0.04151
# Training Results  - Epoch: 15 Avg accuracy: 0.78002, Avg BCE: 0.50843, F1 Score: 0.19662, ROC_AUC: 0.69815
# Training Results  - Epoch: 15 Precision: 0.72226, Recall: 0.11380
# Validation Results- Epoch: 15 Avg accuracy: 0.77553, Avg BCE: 0.53666, F1 Score: 0.06798, ROC_AUC: 0.57373
# Validation Results- Epoch: 15 Precision: 0.28440, Recall: 0.03861
# Training Results  - Epoch: 16 Avg accuracy: 0.77889, Avg BCE: 0.51063, F1 Score: 0.18914, ROC_AUC: 0.69511
# Training Results  - Epoch: 16 Precision: 0.71357, Recall: 0.10902
# Validation Results- Epoch: 16 Avg accuracy: 0.77280, Avg BCE: 0.53880, F1 Score: 0.06722, ROC_AUC: 0.56920
# Validation Results- Epoch: 16 Precision: 0.25978, Recall: 0.03861
# Training Results  - Epoch: 17 Avg accuracy: 0.77946, Avg BCE: 0.51356, F1 Score: 0.19846, ROC_AUC: 0.69285
# Training Results  - Epoch: 17 Precision: 0.70726, Recall: 0.11542
# Validation Results- Epoch: 17 Avg accuracy: 0.77174, Avg BCE: 0.54241, F1 Score: 0.06961, ROC_AUC: 0.56751
# Validation Results- Epoch: 17 Precision: 0.25661, Recall: 0.04027
# Training Results  - Epoch: 18 Avg accuracy: 0.77801, Avg BCE: 0.51271, F1 Score: 0.18286, ROC_AUC: 0.69141
# Training Results  - Epoch: 18 Precision: 0.70721, Recall: 0.10501
# Validation Results- Epoch: 18 Avg accuracy: 0.77518, Avg BCE: 0.53897, F1 Score: 0.05965, ROC_AUC: 0.56980
# Validation Results- Epoch: 18 Precision: 0.26384, Recall: 0.03362
# Training Results  - Epoch: 19 Avg accuracy: 0.77794, Avg BCE: 0.51354, F1 Score: 0.19381, ROC_AUC: 0.69182
# Training Results  - Epoch: 19 Precision: 0.68623, Recall: 0.11284
# Validation Results- Epoch: 19 Avg accuracy: 0.77218, Avg BCE: 0.53820, F1 Score: 0.08162, ROC_AUC: 0.57901
# Validation Results- Epoch: 19 Precision: 0.28117, Recall: 0.04774
# Training Results  - Epoch: 20 Avg accuracy: 0.77609, Avg BCE: 0.51583, F1 Score: 0.18400, ROC_AUC: 0.68409
# Training Results  - Epoch: 20 Precision: 0.66687, Recall: 0.10673
# Validation Results- Epoch: 20 Avg accuracy: 0.77509, Avg BCE: 0.53798, F1 Score: 0.08913, ROC_AUC: 0.57471
# Validation Results- Epoch: 20 Precision: 0.31566, Recall: 0.05189
# Training Results  - Epoch: 21 Avg accuracy: 0.77733, Avg BCE: 0.51403, F1 Score: 0.20867, ROC_AUC: 0.69106
# Training Results  - Epoch: 21 Precision: 0.65474, Recall: 0.12412
# Validation Results- Epoch: 21 Avg accuracy: 0.77016, Avg BCE: 0.54136, F1 Score: 0.09246, ROC_AUC: 0.57499
# Validation Results- Epoch: 21 Precision: 0.28419, Recall: 0.05521
# Training Results  - Epoch: 22 Avg accuracy: 0.77918, Avg BCE: 0.51130, F1 Score: 0.19042, ROC_AUC: 0.69363
# Training Results  - Epoch: 22 Precision: 0.71723, Recall: 0.10978
# Validation Results- Epoch: 22 Avg accuracy: 0.77113, Avg BCE: 0.54064, F1 Score: 0.07209, ROC_AUC: 0.57053
# Validation Results- Epoch: 22 Precision: 0.25700, Recall: 0.04193
# Training Results  - Epoch: 23 Avg accuracy: 0.78009, Avg BCE: 0.51106, F1 Score: 0.20584, ROC_AUC: 0.69541
# Training Results  - Epoch: 23 Precision: 0.70605, Recall: 0.12049
# Validation Results- Epoch: 23 Avg accuracy: 0.77148, Avg BCE: 0.53970, F1 Score: 0.08848, ROC_AUC: 0.57660
# Validation Results- Epoch: 23 Precision: 0.28702, Recall: 0.05230
# Training Results  - Epoch: 24 Avg accuracy: 0.77846, Avg BCE: 0.51330, F1 Score: 0.20036, ROC_AUC: 0.69060
# Training Results  - Epoch: 24 Precision: 0.68527, Recall: 0.11733
# Validation Results- Epoch: 24 Avg accuracy: 0.77095, Avg BCE: 0.54069, F1 Score: 0.08509, ROC_AUC: 0.57650
# Validation Results- Epoch: 24 Precision: 0.27816, Recall: 0.05023
# Training Results  - Epoch: 25 Avg accuracy: 0.77880, Avg BCE: 0.51243, F1 Score: 0.17874, ROC_AUC: 0.68996
# Training Results  - Epoch: 25 Precision: 0.73398, Recall: 0.10176
# Validation Results- Epoch: 25 Avg accuracy: 0.77606, Avg BCE: 0.53859, F1 Score: 0.06333, ROC_AUC: 0.56892
# Validation Results- Epoch: 25 Precision: 0.28013, Recall: 0.03570
# Training Results  - Epoch: 26 Avg accuracy: 0.77738, Avg BCE: 0.51360, F1 Score: 0.19116, ROC_AUC: 0.69014
# Training Results  - Epoch: 26 Precision: 0.67991, Recall: 0.11122
# Validation Results- Epoch: 26 Avg accuracy: 0.77324, Avg BCE: 0.54131, F1 Score: 0.08066, ROC_AUC: 0.57022
# Validation Results- Epoch: 26 Precision: 0.28753, Recall: 0.04691
# Training Results  - Epoch: 27 Avg accuracy: 0.77796, Avg BCE: 0.51281, F1 Score: 0.19157, ROC_AUC: 0.69560
# Training Results  - Epoch: 27 Precision: 0.69039, Recall: 0.11122
# Validation Results- Epoch: 27 Avg accuracy: 0.77333, Avg BCE: 0.54082, F1 Score: 0.08785, ROC_AUC: 0.57556
# Validation Results- Epoch: 27 Precision: 0.29952, Recall: 0.05147
# Training Results  - Epoch: 28 Avg accuracy: 0.77916, Avg BCE: 0.50982, F1 Score: 0.17953, ROC_AUC: 0.69718
# Training Results  - Epoch: 28 Precision: 0.74082, Recall: 0.10214
# Validation Results- Epoch: 28 Avg accuracy: 0.77729, Avg BCE: 0.53535, F1 Score: 0.07190, ROC_AUC: 0.57528
# Validation Results- Epoch: 28 Precision: 0.30915, Recall: 0.04068
# Training Results  - Epoch: 29 Avg accuracy: 0.78138, Avg BCE: 0.51135, F1 Score: 0.19919, ROC_AUC: 0.69831
# Training Results  - Epoch: 29 Precision: 0.74582, Recall: 0.11494
# Validation Results- Epoch: 29 Avg accuracy: 0.77227, Avg BCE: 0.53987, F1 Score: 0.06234, ROC_AUC: 0.57339
# Validation Results- Epoch: 29 Precision: 0.24571, Recall: 0.03570
# Training Results  - Epoch: 30 Avg accuracy: 0.78097, Avg BCE: 0.50968, F1 Score: 0.20767, ROC_AUC: 0.70124
# Training Results  - Epoch: 30 Precision: 0.71955, Recall: 0.12135
# Validation Results- Epoch: 30 Avg accuracy: 0.77306, Avg BCE: 0.54375, F1 Score: 0.08517, ROC_AUC: 0.56610
# Validation Results- Epoch: 30 Precision: 0.29340, Recall: 0.04981
# Training Results  - Epoch: 31 Avg accuracy: 0.77923, Avg BCE: 0.51067, F1 Score: 0.19433, ROC_AUC: 0.69893
# Training Results  - Epoch: 31 Precision: 0.71049, Recall: 0.11255
# Validation Results- Epoch: 31 Avg accuracy: 0.77632, Avg BCE: 0.53909, F1 Score: 0.06821, ROC_AUC: 0.56986
# Validation Results- Epoch: 31 Precision: 0.29245, Recall: 0.03861
# Training Results  - Epoch: 32 Avg accuracy: 0.78097, Avg BCE: 0.51140, F1 Score: 0.20702, ROC_AUC: 0.69699
# Training Results  - Epoch: 32 Precision: 0.72080, Recall: 0.12087
# Validation Results- Epoch: 32 Avg accuracy: 0.77491, Avg BCE: 0.53872, F1 Score: 0.08515, ROC_AUC: 0.57786
# Validation Results- Epoch: 32 Precision: 0.30829, Recall: 0.04940
# Training Results  - Epoch: 33 Avg accuracy: 0.78151, Avg BCE: 0.51053, F1 Score: 0.21858, ROC_AUC: 0.69967
# Training Results  - Epoch: 33 Precision: 0.70971, Recall: 0.12918
# Validation Results- Epoch: 33 Avg accuracy: 0.77298, Avg BCE: 0.54373, F1 Score: 0.09667, ROC_AUC: 0.56968
# Validation Results- Epoch: 33 Precision: 0.30942, Recall: 0.05729
# Training Results  - Epoch: 34 Avg accuracy: 0.78009, Avg BCE: 0.51059, F1 Score: 0.20727, ROC_AUC: 0.69652
# Training Results  - Epoch: 34 Precision: 0.70354, Recall: 0.12154
# Validation Results- Epoch: 34 Avg accuracy: 0.77491, Avg BCE: 0.54340, F1 Score: 0.09165, ROC_AUC: 0.56666
# Validation Results- Epoch: 34 Precision: 0.31773, Recall: 0.05355
# Training Results  - Epoch: 35 Avg accuracy: 0.78025, Avg BCE: 0.51111, F1 Score: 0.19358, ROC_AUC: 0.69488
# Training Results  - Epoch: 35 Precision: 0.73350, Recall: 0.11150
# Validation Results- Epoch: 35 Avg accuracy: 0.77509, Avg BCE: 0.54338, F1 Score: 0.07595, ROC_AUC: 0.56219
# Validation Results- Epoch: 35 Precision: 0.29494, Recall: 0.04359
# Training Results  - Epoch: 36 Avg accuracy: 0.78049, Avg BCE: 0.51187, F1 Score: 0.20873, ROC_AUC: 0.69373
# Training Results  - Epoch: 36 Precision: 0.70852, Recall: 0.12240
# Validation Results- Epoch: 36 Avg accuracy: 0.76963, Avg BCE: 0.54334, F1 Score: 0.09914, ROC_AUC: 0.56877
# Validation Results- Epoch: 36 Precision: 0.29032, Recall: 0.05978
# Training Results  - Epoch: 37 Avg accuracy: 0.77842, Avg BCE: 0.51182, F1 Score: 0.21177, ROC_AUC: 0.69397
# Training Results  - Epoch: 37 Precision: 0.66785, Recall: 0.12584
# Validation Results- Epoch: 37 Avg accuracy: 0.77016, Avg BCE: 0.54458, F1 Score: 0.09997, ROC_AUC: 0.56588
# Validation Results- Epoch: 37 Precision: 0.29472, Recall: 0.06019
# Training Results  - Epoch: 38 Avg accuracy: 0.78124, Avg BCE: 0.50946, F1 Score: 0.21059, ROC_AUC: 0.69936
# Training Results  - Epoch: 38 Precision: 0.71922, Recall: 0.12335
# Validation Results- Epoch: 38 Avg accuracy: 0.76945, Avg BCE: 0.54414, F1 Score: 0.09031, ROC_AUC: 0.56816
# Validation Results- Epoch: 38 Precision: 0.27660, Recall: 0.05396
# Training Results  - Epoch: 39 Avg accuracy: 0.78016, Avg BCE: 0.50994, F1 Score: 0.20460, ROC_AUC: 0.69907
# Training Results  - Epoch: 39 Precision: 0.70959, Recall: 0.11953
# Validation Results- Epoch: 39 Avg accuracy: 0.77377, Avg BCE: 0.54059, F1 Score: 0.08736, ROC_AUC: 0.57292
# Validation Results- Epoch: 39 Precision: 0.30221, Recall: 0.05106
# Training Results  - Epoch: 40 Avg accuracy: 0.78097, Avg BCE: 0.50865, F1 Score: 0.20585, ROC_AUC: 0.70007
# Training Results  - Epoch: 40 Precision: 0.72309, Recall: 0.12001
# Validation Results- Epoch: 40 Avg accuracy: 0.77113, Avg BCE: 0.54555, F1 Score: 0.08900, ROC_AUC: 0.56319
# Validation Results- Epoch: 40 Precision: 0.28539, Recall: 0.05272
# Training Results  - Epoch: 41 Avg accuracy: 0.78022, Avg BCE: 0.51062, F1 Score: 0.21707, ROC_AUC: 0.69783
# Training Results  - Epoch: 41 Precision: 0.68987, Recall: 0.12880
# Validation Results- Epoch: 41 Avg accuracy: 0.77051, Avg BCE: 0.54504, F1 Score: 0.10196, ROC_AUC: 0.56603
# Validation Results- Epoch: 41 Precision: 0.29960, Recall: 0.06144
# Training Results  - Epoch: 42 Avg accuracy: 0.78034, Avg BCE: 0.50867, F1 Score: 0.18920, ROC_AUC: 0.70256
# Training Results  - Epoch: 42 Precision: 0.74556, Recall: 0.10835
# Validation Results- Epoch: 42 Avg accuracy: 0.77518, Avg BCE: 0.54231, F1 Score: 0.08393, ROC_AUC: 0.56561
# Validation Results- Epoch: 42 Precision: 0.30871, Recall: 0.04857
# Training Results  - Epoch: 43 Avg accuracy: 0.78043, Avg BCE: 0.50969, F1 Score: 0.20519, ROC_AUC: 0.70096
# Training Results  - Epoch: 43 Precision: 0.71372, Recall: 0.11982
# Validation Results- Epoch: 43 Avg accuracy: 0.77333, Avg BCE: 0.54439, F1 Score: 0.09171, ROC_AUC: 0.56536
# Validation Results- Epoch: 43 Precision: 0.30516, Recall: 0.05396
# Training Results  - Epoch: 44 Avg accuracy: 0.77557, Avg BCE: 0.51920, F1 Score: 0.15374, ROC_AUC: 0.66045
# Training Results  - Epoch: 44 Precision: 0.71136, Recall: 0.08618
# Validation Results- Epoch: 44 Avg accuracy: 0.77720, Avg BCE: 0.53995, F1 Score: 0.05876, ROC_AUC: 0.55120
# Validation Results- Epoch: 44 Precision: 0.28214, Recall: 0.03279
# Training Results  - Epoch: 45 Avg accuracy: 0.77552, Avg BCE: 0.51828, F1 Score: 0.19186, ROC_AUC: 0.67651
# Training Results  - Epoch: 45 Precision: 0.64638, Recall: 0.11265
# Validation Results- Epoch: 45 Avg accuracy: 0.77201, Avg BCE: 0.54215, F1 Score: 0.07960, ROC_AUC: 0.56656
# Validation Results- Epoch: 45 Precision: 0.27654, Recall: 0.04649
# Training Results  - Epoch: 46 Avg accuracy: 0.78081, Avg BCE: 0.51066, F1 Score: 0.22254, ROC_AUC: 0.70070
# Training Results  - Epoch: 46 Precision: 0.69124, Recall: 0.13262
# Validation Results- Epoch: 46 Avg accuracy: 0.76910, Avg BCE: 0.54384, F1 Score: 0.10447, ROC_AUC: 0.57126
# Validation Results- Epoch: 46 Precision: 0.29423, Recall: 0.06351
# Training Results  - Epoch: 47 Avg accuracy: 0.78063, Avg BCE: 0.51016, F1 Score: 0.21409, ROC_AUC: 0.70264
# Training Results  - Epoch: 47 Precision: 0.70170, Recall: 0.12631
# Validation Results- Epoch: 47 Avg accuracy: 0.77060, Avg BCE: 0.54287, F1 Score: 0.09639, ROC_AUC: 0.57019
# Validation Results- Epoch: 47 Precision: 0.29263, Recall: 0.05770
# Training Results  - Epoch: 48 Avg accuracy: 0.78142, Avg BCE: 0.50942, F1 Score: 0.21521, ROC_AUC: 0.70723
# Training Results  - Epoch: 48 Precision: 0.71405, Recall: 0.12670
# Validation Results- Epoch: 48 Avg accuracy: 0.77254, Avg BCE: 0.54153, F1 Score: 0.09777, ROC_AUC: 0.57633
# Validation Results- Epoch: 48 Precision: 0.30769, Recall: 0.05812
# Training Results  - Epoch: 49 Avg accuracy: 0.78133, Avg BCE: 0.50983, F1 Score: 0.20898, ROC_AUC: 0.70436
# Training Results  - Epoch: 49 Precision: 0.72408, Recall: 0.12211
# Validation Results- Epoch: 49 Avg accuracy: 0.77500, Avg BCE: 0.54108, F1 Score: 0.09426, ROC_AUC: 0.57551
# Validation Results- Epoch: 49 Precision: 0.32203, Recall: 0.05521
# Training Results  - Epoch: 50 Avg accuracy: 0.78151, Avg BCE: 0.50965, F1 Score: 0.21041, ROC_AUC: 0.70416
# Training Results  - Epoch: 50 Precision: 0.72482, Recall: 0.12307
# Validation Results- Epoch: 50 Avg accuracy: 0.77033, Avg BCE: 0.54339, F1 Score: 0.08488, ROC_AUC: 0.57382
# Validation Results- Epoch: 50 Precision: 0.27376, Recall: 0.05023
# Training Results  - Epoch: 51 Avg accuracy: 0.78027, Avg BCE: 0.51064, F1 Score: 0.20985, ROC_AUC: 0.70651
# Training Results  - Epoch: 51 Precision: 0.70239, Recall: 0.12335
# Validation Results- Epoch: 51 Avg accuracy: 0.77359, Avg BCE: 0.54073, F1 Score: 0.09881, ROC_AUC: 0.57792
# Validation Results- Epoch: 51 Precision: 0.31685, Recall: 0.05853
# Training Results  - Epoch: 52 Avg accuracy: 0.78038, Avg BCE: 0.50820, F1 Score: 0.20018, ROC_AUC: 0.70218
# Training Results  - Epoch: 52 Precision: 0.72252, Recall: 0.11619
# Validation Results- Epoch: 52 Avg accuracy: 0.77350, Avg BCE: 0.53832, F1 Score: 0.08074, ROC_AUC: 0.57831
# Validation Results- Epoch: 52 Precision: 0.28974, Recall: 0.04691
# Training Results  - Epoch: 53 Avg accuracy: 0.77914, Avg BCE: 0.50986, F1 Score: 0.19266, ROC_AUC: 0.70118
# Training Results  - Epoch: 53 Precision: 0.71184, Recall: 0.11141
# Validation Results- Epoch: 53 Avg accuracy: 0.77526, Avg BCE: 0.53871, F1 Score: 0.08854, ROC_AUC: 0.57158
# Validation Results- Epoch: 53 Precision: 0.31633, Recall: 0.05147
# Training Results  - Epoch: 54 Avg accuracy: 0.78009, Avg BCE: 0.50812, F1 Score: 0.20533, ROC_AUC: 0.70400
# Training Results  - Epoch: 54 Precision: 0.70697, Recall: 0.12010
# Validation Results- Epoch: 54 Avg accuracy: 0.77509, Avg BCE: 0.53932, F1 Score: 0.08848, ROC_AUC: 0.57096
# Validation Results- Epoch: 54 Precision: 0.31472, Recall: 0.05147
# Training Results  - Epoch: 55 Avg accuracy: 0.78045, Avg BCE: 0.50686, F1 Score: 0.22375, ROC_AUC: 0.70705
# Training Results  - Epoch: 55 Precision: 0.68359, Recall: 0.13377
# Validation Results- Epoch: 55 Avg accuracy: 0.77183, Avg BCE: 0.54168, F1 Score: 0.10621, ROC_AUC: 0.57137
# Validation Results- Epoch: 55 Precision: 0.31365, Recall: 0.06393
# Training Results  - Epoch: 56 Avg accuracy: 0.78068, Avg BCE: 0.50730, F1 Score: 0.23711, ROC_AUC: 0.71115
# Training Results  - Epoch: 56 Precision: 0.66903, Recall: 0.14409
# Validation Results- Epoch: 56 Avg accuracy: 0.76989, Avg BCE: 0.54411, F1 Score: 0.10602, ROC_AUC: 0.56990
# Validation Results- Epoch: 56 Precision: 0.30097, Recall: 0.06434
# Training Results  - Epoch: 57 Avg accuracy: 0.78052, Avg BCE: 0.50803, F1 Score: 0.22517, ROC_AUC: 0.70660
# Training Results  - Epoch: 57 Precision: 0.68263, Recall: 0.13482
# Validation Results- Epoch: 57 Avg accuracy: 0.77298, Avg BCE: 0.54162, F1 Score: 0.11222, ROC_AUC: 0.57319
# Validation Results- Epoch: 57 Precision: 0.32863, Recall: 0.06766
# Training Results  - Epoch: 58 Avg accuracy: 0.77891, Avg BCE: 0.50974, F1 Score: 0.22105, ROC_AUC: 0.70344
# Training Results  - Epoch: 58 Precision: 0.66348, Recall: 0.13262
# Validation Results- Epoch: 58 Avg accuracy: 0.77165, Avg BCE: 0.54231, F1 Score: 0.10981, ROC_AUC: 0.57776
# Validation Results- Epoch: 58 Precision: 0.31683, Recall: 0.06642
# Training Results  - Epoch: 59 Avg accuracy: 0.77724, Avg BCE: 0.51091, F1 Score: 0.20924, ROC_AUC: 0.69707
# Training Results  - Epoch: 59 Precision: 0.65265, Recall: 0.12459
# Validation Results- Epoch: 59 Avg accuracy: 0.77025, Avg BCE: 0.54370, F1 Score: 0.09501, ROC_AUC: 0.57067
# Validation Results- Epoch: 59 Precision: 0.28842, Recall: 0.05687
# Training Results  - Epoch: 60 Avg accuracy: 0.78072, Avg BCE: 0.50760, F1 Score: 0.22951, ROC_AUC: 0.70717
# Training Results  - Epoch: 60 Precision: 0.67968, Recall: 0.13807
# Validation Results- Epoch: 60 Avg accuracy: 0.77025, Avg BCE: 0.54425, F1 Score: 0.10309, ROC_AUC: 0.57266
# Validation Results- Epoch: 60 Precision: 0.29940, Recall: 0.06227
# Training Results  - Epoch: 61 Avg accuracy: 0.77814, Avg BCE: 0.51060, F1 Score: 0.20775, ROC_AUC: 0.69129
# Training Results  - Epoch: 61 Precision: 0.66892, Recall: 0.12297
# Validation Results- Epoch: 61 Avg accuracy: 0.76761, Avg BCE: 0.54680, F1 Score: 0.08206, ROC_AUC: 0.56042
# Validation Results- Epoch: 61 Precision: 0.25268, Recall: 0.04898
# Training Results  - Epoch: 62 Avg accuracy: 0.78174, Avg BCE: 0.50571, F1 Score: 0.23058, ROC_AUC: 0.71085
# Training Results  - Epoch: 62 Precision: 0.69400, Recall: 0.13826
# Validation Results- Epoch: 62 Avg accuracy: 0.76972, Avg BCE: 0.54210, F1 Score: 0.09979, ROC_AUC: 0.57311
# Validation Results- Epoch: 62 Precision: 0.29175, Recall: 0.06019
# Training Results  - Epoch: 63 Avg accuracy: 0.77909, Avg BCE: 0.50797, F1 Score: 0.23051, ROC_AUC: 0.70670
# Training Results  - Epoch: 63 Precision: 0.65474, Recall: 0.13988
# Validation Results- Epoch: 63 Avg accuracy: 0.76937, Avg BCE: 0.54652, F1 Score: 0.10335, ROC_AUC: 0.56609
# Validation Results- Epoch: 63 Precision: 0.29435, Recall: 0.06268
# Training Results  - Epoch: 64 Avg accuracy: 0.77568, Avg BCE: 0.51254, F1 Score: 0.22443, ROC_AUC: 0.69583
# Training Results  - Epoch: 64 Precision: 0.61604, Recall: 0.13721
# Validation Results- Epoch: 64 Avg accuracy: 0.76769, Avg BCE: 0.54824, F1 Score: 0.12063, ROC_AUC: 0.56464
# Validation Results- Epoch: 64 Precision: 0.30574, Recall: 0.07513
# Training Results  - Epoch: 65 Avg accuracy: 0.78036, Avg BCE: 0.50786, F1 Score: 0.23468, ROC_AUC: 0.70691
# Training Results  - Epoch: 65 Precision: 0.66756, Recall: 0.14237
# Validation Results- Epoch: 65 Avg accuracy: 0.76866, Avg BCE: 0.54386, F1 Score: 0.10915, ROC_AUC: 0.57054
# Validation Results- Epoch: 65 Precision: 0.29760, Recall: 0.06683
# Training Results  - Epoch: 66 Avg accuracy: 0.78072, Avg BCE: 0.50842, F1 Score: 0.23858, ROC_AUC: 0.70746
# Training Results  - Epoch: 66 Precision: 0.66784, Recall: 0.14523
# Validation Results- Epoch: 66 Avg accuracy: 0.76646, Avg BCE: 0.54738, F1 Score: 0.11182, ROC_AUC: 0.56609
# Validation Results- Epoch: 66 Precision: 0.28893, Recall: 0.06932
# Training Results  - Epoch: 67 Avg accuracy: 0.78165, Avg BCE: 0.50734, F1 Score: 0.23767, ROC_AUC: 0.71065
# Training Results  - Epoch: 67 Precision: 0.68237, Recall: 0.14389
# Validation Results- Epoch: 67 Avg accuracy: 0.76901, Avg BCE: 0.54692, F1 Score: 0.10566, ROC_AUC: 0.56806
# Validation Results- Epoch: 67 Precision: 0.29524, Recall: 0.06434
# Training Results  - Epoch: 68 Avg accuracy: 0.78088, Avg BCE: 0.50570, F1 Score: 0.24145, ROC_AUC: 0.71018
# Training Results  - Epoch: 68 Precision: 0.66652, Recall: 0.14743
# Validation Results- Epoch: 68 Avg accuracy: 0.76734, Avg BCE: 0.54422, F1 Score: 0.10920, ROC_AUC: 0.57104
# Validation Results- Epoch: 68 Precision: 0.29032, Recall: 0.06725
# Training Results  - Epoch: 69 Avg accuracy: 0.78104, Avg BCE: 0.50420, F1 Score: 0.24087, ROC_AUC: 0.70993
# Training Results  - Epoch: 69 Precision: 0.66943, Recall: 0.14686
# Validation Results- Epoch: 69 Avg accuracy: 0.77086, Avg BCE: 0.54229, F1 Score: 0.11191, ROC_AUC: 0.57004
# Validation Results- Epoch: 69 Precision: 0.31418, Recall: 0.06808
# Training Results  - Epoch: 70 Avg accuracy: 0.78072, Avg BCE: 0.50761, F1 Score: 0.27293, ROC_AUC: 0.71020
# Training Results  - Epoch: 70 Precision: 0.63273, Recall: 0.17399
# Validation Results- Epoch: 70 Avg accuracy: 0.76320, Avg BCE: 0.54989, F1 Score: 0.13058, ROC_AUC: 0.57269
# Validation Results- Epoch: 70 Precision: 0.29489, Recall: 0.08385
# Training Results  - Epoch: 71 Avg accuracy: 0.77921, Avg BCE: 0.51099, F1 Score: 0.23266, ROC_AUC: 0.70085
# Training Results  - Epoch: 71 Precision: 0.65386, Recall: 0.14151
# Validation Results- Epoch: 71 Avg accuracy: 0.76681, Avg BCE: 0.54882, F1 Score: 0.11788, ROC_AUC: 0.56023
# Validation Results- Epoch: 71 Precision: 0.29798, Recall: 0.07347
# Training Results  - Epoch: 72 Avg accuracy: 0.77670, Avg BCE: 0.51273, F1 Score: 0.25163, ROC_AUC: 0.69739
# Training Results  - Epoch: 72 Precision: 0.60709, Recall: 0.15870
# Validation Results- Epoch: 72 Avg accuracy: 0.76109, Avg BCE: 0.55236, F1 Score: 0.11826, ROC_AUC: 0.56119
# Validation Results- Epoch: 72 Precision: 0.27205, Recall: 0.07555
# Training Results  - Epoch: 73 Avg accuracy: 0.78131, Avg BCE: 0.50601, F1 Score: 0.25328, ROC_AUC: 0.71155
# Training Results  - Epoch: 73 Precision: 0.65851, Recall: 0.15679
# Validation Results- Epoch: 73 Avg accuracy: 0.76461, Avg BCE: 0.54784, F1 Score: 0.12155, ROC_AUC: 0.57049
# Validation Results- Epoch: 73 Precision: 0.29134, Recall: 0.07680
# Training Results  - Epoch: 74 Avg accuracy: 0.78138, Avg BCE: 0.50560, F1 Score: 0.24776, ROC_AUC: 0.71000
# Training Results  - Epoch: 74 Precision: 0.66569, Recall: 0.15221
# Validation Results- Epoch: 74 Avg accuracy: 0.76805, Avg BCE: 0.54740, F1 Score: 0.12020, ROC_AUC: 0.56335
# Validation Results- Epoch: 74 Precision: 0.30717, Recall: 0.07472
# Training Results  - Epoch: 75 Avg accuracy: 0.77921, Avg BCE: 0.50727, F1 Score: 0.22720, ROC_AUC: 0.70335
# Training Results  - Epoch: 75 Precision: 0.66023, Recall: 0.13721
# Validation Results- Epoch: 75 Avg accuracy: 0.76963, Avg BCE: 0.54309, F1 Score: 0.10100, ROC_AUC: 0.56872
# Validation Results- Epoch: 75 Precision: 0.29283, Recall: 0.06102
# Training Results  - Epoch: 76 Avg accuracy: 0.78009, Avg BCE: 0.50669, F1 Score: 0.24981, ROC_AUC: 0.70825
# Training Results  - Epoch: 76 Precision: 0.64696, Recall: 0.15479
# Validation Results- Epoch: 76 Avg accuracy: 0.76426, Avg BCE: 0.54690, F1 Score: 0.12197, ROC_AUC: 0.56479
# Validation Results- Epoch: 76 Precision: 0.29017, Recall: 0.07721
# Training Results  - Epoch: 77 Avg accuracy: 0.77828, Avg BCE: 0.51069, F1 Score: 0.25738, ROC_AUC: 0.69914
# Training Results  - Epoch: 77 Precision: 0.61953, Recall: 0.16243
# Validation Results- Epoch: 77 Avg accuracy: 0.76241, Avg BCE: 0.54950, F1 Score: 0.13742, ROC_AUC: 0.56917
# Validation Results- Epoch: 77 Precision: 0.29861, Recall: 0.08925
# Training Results  - Epoch: 78 Avg accuracy: 0.77986, Avg BCE: 0.50840, F1 Score: 0.24660, ROC_AUC: 0.70588
# Training Results  - Epoch: 78 Precision: 0.64744, Recall: 0.15230
# Validation Results- Epoch: 78 Avg accuracy: 0.76593, Avg BCE: 0.54892, F1 Score: 0.12504, ROC_AUC: 0.56602
# Validation Results- Epoch: 78 Precision: 0.30159, Recall: 0.07887
# Training Results  - Epoch: 79 Avg accuracy: 0.77701, Avg BCE: 0.51031, F1 Score: 0.25416, ROC_AUC: 0.69786
# Training Results  - Epoch: 79 Precision: 0.60862, Recall: 0.16062
# Validation Results- Epoch: 79 Avg accuracy: 0.75995, Avg BCE: 0.54841, F1 Score: 0.13236, ROC_AUC: 0.57369
# Validation Results- Epoch: 79 Precision: 0.28338, Recall: 0.08634
# Training Results  - Epoch: 80 Avg accuracy: 0.77932, Avg BCE: 0.50653, F1 Score: 0.25283, ROC_AUC: 0.70527
# Training Results  - Epoch: 80 Precision: 0.63490, Recall: 0.15784
# Validation Results- Epoch: 80 Avg accuracy: 0.76391, Avg BCE: 0.54670, F1 Score: 0.13428, ROC_AUC: 0.56968
# Validation Results- Epoch: 80 Precision: 0.30189, Recall: 0.08634

# %%
binary_y_test.mean()
# Out:
# marketHigh_-20    0.260563
# marketLow_-20     0.268046
# marketHigh_-10    0.196743
# marketLow_-10     0.211268
# marketHigh_-5     0.123680
# dtype: float64
