# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

from scipy import optimize

import tensorflow as tf
import torch
import os
os.chdir('..')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import datetime
import matplotlib as mpl
from matplotlib import cm
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline, FeatureUnion

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
def train_df_test_df(ticker):
    
    def concat_and_return_csvs(original_df, ticker_files):
        for item in ticker_files[1:]:
            this_df = pd.read_csv(data_path+item)
            original_df = pd.concat([original_df, this_df])
        return original_df
    
    data_path = 'data/daily_data/'
    ticker_files = [item for item in os.listdir(data_path) if ticker in item.split('_')]
    ticker_files.sort()
    
    split_idx = int(len(ticker_files) * 0.8)
    train_ticker_files, test_ticker_files = ticker_files[:split_idx], ticker_files[split_idx:]

    train_df = pd.read_csv(data_path+train_ticker_files[0])
    train_df = concat_and_return_csvs(train_df, train_ticker_files)
    
    test_df = pd.read_csv(data_path+test_ticker_files[0])
    test_df = concat_and_return_csvs(test_df, test_ticker_files)
    
    return train_df, test_df

# %%
def get_processed_minute_data(df):
    cols = df.columns.tolist()
    cols_to_drop = cols[:4] + ['label', 'changeOverTime', 'close', 'high', 
                               'low', 'marketAverage', 'marketClose', 
                               'marketOpen', 'volume', 'numberOfTrades', 
                               'notional', 'open', 'marketChangeOverTime']
    df.drop(cols_to_drop, axis=1, inplace=True)
    # necessary
    df.reset_index(drop=True, inplace=True)
    
    idx_to_drop = df.index[df.marketNotional == 0.0]
    df.drop(idx_to_drop, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    df.date = df.date.map(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))
    df['weekday'] = df.date.map(lambda x: str(x.weekday()))
    df['month']   = df.date.map(lambda x: str(x.month))
    
    df.minute = df.minute.map(lambda x: datetime.datetime.strptime(x, '%H:%M'))
    df['hour'] = df.minute.map(lambda x: str(x.hour))
    
    return df

# %%
def get_numeric_categoric(df):
    numeric_cols, categorical_cols = [], []

    for col in df:
        if np.issubdtype(df[col].dtype, np.number):
            numeric_cols += [col]
        else:
            categorical_cols += [col]
    
    return numeric_cols, categorical_cols

# %%
def delta_dataframe(df, numeric_columns):
    '''
    log numerical columns, then return deltas
    '''
    
    MAX_SHIFT_BACWARD, MAX_SHIFT_FORWARD = -20, 20
    added_columns = []
    for shift in [MAX_SHIFT_BACWARD, -10, -5, 3, 5, 10, MAX_SHIFT_FORWARD]:
        for col in numeric_columns:
            new_col_name = col + '_' + str(shift)
            df[new_col_name] = df[col].shift(shift)
            added_columns += [new_col_name]

    df[numeric_columns+added_columns] = df[numeric_columns+added_columns].apply(np.log)
    
    # for lookbacks
    for new_col in added_columns:
        original_col, added_part = new_col.split('_')
        df[new_col] = df[new_col] - df[original_col] if '-' in added_part else \
                      df[original_col] - df[new_col]

    # for today
    # This line is necessary
    temp = df[numeric_columns] - df[numeric_columns].shift(1)
    df[numeric_columns] = temp
    
    assert (df.index == np.arange(len(df))).all()
    df.drop(df.index[list(range(MAX_SHIFT_FORWARD))], axis=0, inplace=True)
    df.reset_index(drop=True, inplace=True)
    #                            negative max_shift_back...
    df.drop(index=list(range(len(df)+MAX_SHIFT_BACWARD, len(df))), inplace=True)
    
    return df

# %%
def load_dataframes(ticker):
    train_df, test_df = train_df_test_df(ticker)
    
#     train_df, test_df = list(map(lambda x: get_processed_minute_data(x), 
#                                  (train_df, test_df)))
    train_df = get_processed_minute_data(train_df)
    test_df  = get_processed_minute_data(test_df)
    
    numeric_cols, categoric_cols = get_numeric_categoric(train_df)
    # This is for the time being...
    categoric_cols = ['weekday', 'month', 'hour']
    
    train_df = delta_dataframe(train_df, numeric_cols)
    test_df  = delta_dataframe(test_df,  numeric_cols)
    
    # Re-evaluate column names from the deltas
    numeric_cols, _ = get_numeric_categoric(train_df)
    
    return train_df, test_df, numeric_cols, categoric_cols

def get_y_cols(numeric_cols):
    price_cols      = [item for item in numeric_cols if '-' in item]
    interested_cols = [item for item in price_cols if 'High' in item or 'Low' in item]
    not_interested_cols = list(set(price_cols) - set(interested_cols))
    return interested_cols, not_interested_cols

# messy code... 
train_df_original, test_df_original, numeric_cols, categoric_cols = load_dataframes('cmg')
y_cols, not_interested = get_y_cols(numeric_cols)
numeric_cols = list(set(numeric_cols) - set(y_cols) - set(not_interested))

# %%
train_df, y_train = train_df_original[numeric_cols], train_df_original[y_cols]
test_df, y_test   = test_df_original[numeric_cols], test_df_original[y_cols]
y_train.drop(y_train.columns[2:], axis=1, inplace=True)
y_test.drop( y_test.columns[2:], axis=1, inplace=True)
binary_y_train = (y_train>0.002).astype(np.int)
binary_y_test  = (y_test >0.002 ).astype(np.int)

# %%
# Use only the ones worked well in autoencoder
transfomer = [
    ('Data after min-max scaling',
        MinMaxScaler()),
    ('Data after max-abs scaling',
        MaxAbsScaler()),
    ('Data after quantile transformation (uniform pdf)',
        QuantileTransformer(output_distribution='uniform')),
    ('Data after sample-wise L2 normalizing',
        Normalizer()),
]

combined = FeatureUnion(transfomer)
combined_fit = combined.fit(train_df)

# %%
x_train_transformed = combined.transform(train_df)
x_test_transformed = combined.transform(test_df)

# %%
x_train_transformed.shape, x_test_transformed.shape
# Out:
# ((9229, 100), (2274, 100))

# %%
class LogisticRegressor(nn.Module):
    def __init__(self, input_size, final_output_size):
        super(LogisticRegressor, self).__init__()

        self.l1 = nn.Linear(input_size, 32)
        self.l2 = nn.Linear(32, 16)
#         self.l3 = nn.Linear(32, 16)
        self.l4 = nn.Linear(16, final_output_size)

    def forward(self, x):
        x = torch.relu(self.l1(x))
        x = torch.tanh(self.l2(x))
#         x = torch.tanh(self.l3(x))
        return torch.sigmoid(self.l4(x))

# %%
class TickerDataSimple(Dataset):
    def __init__(self, ticker, x, y):
        '''
        :param ticker: string
        :param x: np.array of x
        :param y: np.array of y
        '''
        self.ticker = ticker
        self.x = torch.FloatTensor(x)
        self.y = torch.FloatTensor(y)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, index):
        x = self.x[index]
        y = self.y[index]
        return x, y

# %%
x_train_transformed = combined.transform(train_df)
x_test_transformed = combined.transform(test_df)

spy_dataset = TickerDataSimple('spy', x_train_transformed, 
                               torch.from_numpy(binary_y_train.values).float())

BATCH_SIZE = 64
train_dl = DataLoader(spy_dataset, 
                      num_workers=1, 
                      batch_size=BATCH_SIZE)

spy_testset = TickerDataSimple('spy', x_test_transformed, 
                               torch.from_numpy(binary_y_test.values).float())

BATCH_SIZE = 64
test_dl = DataLoader(spy_testset, 
                      num_workers=1, 
                      batch_size=BATCH_SIZE)

# %%
iter_train_dl = iter(train_dl)

# %%
x, y = next(iter_train_dl)
x.shape, y.shape
# Out:
# (torch.Size([64, 100]), torch.Size([64, 2]))

# %%
class CustomLoss(torch.nn.Module):
    '''
    Implement Focal Loss
    '''
    def __init__(self):
        super(CustomLoss,self).__init__()
        
    def forward(self, y_pred, y_target):
        y_pred = y_pred.flatten()
        y_target = y_target.flatten()
        
        def log_p(pred, target):
            return -((1-pred) * torch.log2(pred) * target)
        
        return (log_p(y_pred, y_target) + log_p(1-y_pred, 1-y_target)).mean()

# %%
from torch.nn.utils import clip_grad_norm_
import torch.optim as optim

# Each Data Points are 24 (6 * 4)
# Transformer has 4 different ways
model = LogisticRegressor(x_train_transformed.shape[1], y_train.shape[1])

# criterion = CustomLoss()
criterion = torch.nn.BCELoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=5e-3, weight_decay=1e-6)

# %%
import ignite
from ignite.metrics import BinaryAccuracy, Loss, Precision, Recall
from ignite.engine import Events, \
                          create_supervised_trainer, \
                          create_supervised_evaluator

# %%
import sklearn.metrics as sk_metrics
import torch.nn.functional as F

# %%
# iter_train_dl = iter(train_dl)

# %%
# x, y = next(iter_train_dl)
# _out = model(x)
# _out = _out.flatten()
# y    = y.flatten()
# _zero_one = _out > 0.5
# print('f1_score: {}'.format(sk_metrics.f1_score(_zero_one.detach().numpy(), y)))
# print('accuracy_score: {}'.format(sk_metrics.accuracy_score(_zero_one, y)))
# print('roc_auc_score: {}'.format(sk_metrics.roc_auc_score(y, _out.detach().numpy())))

# %%
from ignite.metrics import Accuracy
from functools import partial
from sklearn.metrics import roc_auc_score
from ignite.metrics import EpochMetric


def sk_metric_fn(y_preds, y_targets, sk_metrics, activation=None):
    y_true = y_targets.flatten().numpy()
    y_pred = y_preds.flatten().numpy()
    if activation is not None:
        y_preds = activation(y_preds)
    
    return sk_metrics(y_true, y_pred)

class ROC_AUC(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(ROC_AUC, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.roc_auc_score, 
                    activation=activation),
            output_transform=output_transform)

class F1_Score(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(F1_Score, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.f1_score, 
                    activation=activation),
            output_transform=output_transform)

class BinaryAccuracy(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(BinaryAccuracy, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.accuracy_score, 
                    activation=activation),
            output_transform=output_transform)

class Precision(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(Precision, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.precision_score, 
                    activation=activation),
            output_transform=output_transform)

class Recall(EpochMetric):
    def __init__(self, activation=None, output_transform=lambda x: x):
        super(Recall, self).__init__(
            partial(sk_metric_fn, 
                    sk_metrics=sk_metrics.recall_score, 
                    activation=activation),
            output_transform=output_transform)

# %%
def zero_one(y_preds):
    return y_preds > 0.5
    
def zero_one_transform(output):
    return (zero_one(output[0])).long(), output[1].long()

# %%
bce_loss = nn.modules.loss.BCELoss()

trainer = create_supervised_trainer(model, optimizer, criterion)
evaluator = create_supervised_evaluator(
    model,
    metrics={
        'accuracy' : BinaryAccuracy(output_transform=zero_one_transform),
        'bce':       Loss(bce_loss),
        'f1_score' : F1_Score(output_transform=zero_one_transform),
        'roc_auc'  : ROC_AUC(),
        'precision': Precision(output_transform=zero_one_transform),
        'recall'   : Recall(output_transform=zero_one_transform),
    })

# %%
@trainer.on(Events.EPOCH_COMPLETED)
def log_training_results(trainer):
    evaluator.run(train_dl)
    metrics = evaluator.state.metrics
    print("Training Results  - Epoch: {} Avg accuracy: {:.5f}, Avg BCE: {:.5f}, F1 Score: {:.5f}, ROC_AUC: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['accuracy'], 
                  metrics['bce'],
                  metrics['f1_score'],
                  metrics['roc_auc'],
                 ))
    print("Training Results  - Epoch: {} Precision: {:.5f}, Recall: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['precision'], 
                  metrics['recall'],
                 ))

@trainer.on(Events.EPOCH_COMPLETED)
def log_validation_results(trainer):
    evaluator.run(test_dl)
    metrics = evaluator.state.metrics
    print("Validation Results- Epoch: {} Avg accuracy: {:.5f}, Avg BCE: {:.5f}, F1 Score: {:.5f}, ROC_AUC: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['accuracy'], 
                  metrics['bce'],
                  metrics['f1_score'],
                  metrics['roc_auc'],
                 ))
    print("Validation Results- Epoch: {} Precision: {:.5f}, Recall: {:.5f}".format(
                  trainer.state.epoch, 
                  metrics['precision'],
                  metrics['recall'],
                 ))

# %%
trainer.run(train_dl, max_epochs=100)
# Out:
# Training Results  - Epoch: 1 Avg accuracy: 0.70143, Avg BCE: 0.62274, F1 Score: 0.00000, ROC_AUC: 0.50290
# Training Results  - Epoch: 1 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 1 Avg accuracy: 0.73835, Avg BCE: 0.57927, F1 Score: 0.00000, ROC_AUC: 0.49333
# Validation Results- Epoch: 1 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 2 Avg accuracy: 0.70143, Avg BCE: 0.61737, F1 Score: 0.00000, ROC_AUC: 0.50519
# Training Results  - Epoch: 2 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 2 Avg accuracy: 0.73835, Avg BCE: 0.57713, F1 Score: 0.00000, ROC_AUC: 0.49640
# Validation Results- Epoch: 2 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 3 Avg accuracy: 0.70143, Avg BCE: 0.61642, F1 Score: 0.00000, ROC_AUC: 0.50963
# Training Results  - Epoch: 3 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 3 Avg accuracy: 0.73835, Avg BCE: 0.57668, F1 Score: 0.00000, ROC_AUC: 0.49983
# Validation Results- Epoch: 3 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 4 Avg accuracy: 0.70143, Avg BCE: 0.61409, F1 Score: 0.00000, ROC_AUC: 0.51625
# Training Results  - Epoch: 4 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 4 Avg accuracy: 0.73835, Avg BCE: 0.57562, F1 Score: 0.00000, ROC_AUC: 0.50298
# Validation Results- Epoch: 4 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 5 Avg accuracy: 0.70143, Avg BCE: 0.61422, F1 Score: 0.00000, ROC_AUC: 0.51921
# Training Results  - Epoch: 5 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 5 Avg accuracy: 0.73835, Avg BCE: 0.57583, F1 Score: 0.00000, ROC_AUC: 0.50338
# Validation Results- Epoch: 5 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 6 Avg accuracy: 0.70143, Avg BCE: 0.61338, F1 Score: 0.00000, ROC_AUC: 0.52250
# Training Results  - Epoch: 6 Precision: 0.00000, Recall: 0.00000
# Validation Results- Epoch: 6 Avg accuracy: 0.73835, Avg BCE: 0.57558, F1 Score: 0.00000, ROC_AUC: 0.50559
# Validation Results- Epoch: 6 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 7 Avg accuracy: 0.70148, Avg BCE: 0.61272, F1 Score: 0.00036, ROC_AUC: 0.52338
# Training Results  - Epoch: 7 Precision: 1.00000, Recall: 0.00018
# Validation Results- Epoch: 7 Avg accuracy: 0.73835, Avg BCE: 0.57558, F1 Score: 0.00000, ROC_AUC: 0.50686
# Validation Results- Epoch: 7 Precision: 0.00000, Recall: 0.00000
# Training Results  - Epoch: 8 Avg accuracy: 0.70165, Avg BCE: 0.61101, F1 Score: 0.01042, ROC_AUC: 0.52616
# Training Results  - Epoch: 8 Precision: 0.53704, Recall: 0.00526
# Validation Results- Epoch: 8 Avg accuracy: 0.73659, Avg BCE: 0.57524, F1 Score: 0.00828, ROC_AUC: 0.51296
# Validation Results- Epoch: 8 Precision: 0.27778, Recall: 0.00420
# Training Results  - Epoch: 9 Avg accuracy: 0.70159, Avg BCE: 0.60994, F1 Score: 0.02063, ROC_AUC: 0.52963
# Training Results  - Epoch: 9 Precision: 0.51327, Recall: 0.01052
# Validation Results- Epoch: 9 Avg accuracy: 0.73747, Avg BCE: 0.57442, F1 Score: 0.02291, ROC_AUC: 0.51640
# Validation Results- Epoch: 9 Precision: 0.43750, Recall: 0.01176
# Training Results  - Epoch: 10 Avg accuracy: 0.70165, Avg BCE: 0.61062, F1 Score: 0.02548, ROC_AUC: 0.52814
# Training Results  - Epoch: 10 Precision: 0.51429, Recall: 0.01306
# Validation Results- Epoch: 10 Avg accuracy: 0.73747, Avg BCE: 0.57527, F1 Score: 0.02610, ROC_AUC: 0.51316
# Validation Results- Epoch: 10 Precision: 0.44444, Recall: 0.01345
# Training Results  - Epoch: 11 Avg accuracy: 0.70181, Avg BCE: 0.61030, F1 Score: 0.02377, ROC_AUC: 0.53112
# Training Results  - Epoch: 11 Precision: 0.52756, Recall: 0.01216
# Validation Results- Epoch: 11 Avg accuracy: 0.73725, Avg BCE: 0.57507, F1 Score: 0.02449, ROC_AUC: 0.51379
# Validation Results- Epoch: 11 Precision: 0.42857, Recall: 0.01261
# Training Results  - Epoch: 12 Avg accuracy: 0.70224, Avg BCE: 0.60956, F1 Score: 0.02380, ROC_AUC: 0.53412
# Training Results  - Epoch: 12 Precision: 0.56303, Recall: 0.01216
# Validation Results- Epoch: 12 Avg accuracy: 0.73813, Avg BCE: 0.57472, F1 Score: 0.02457, ROC_AUC: 0.51329
# Validation Results- Epoch: 12 Precision: 0.48387, Recall: 0.01261
# Training Results  - Epoch: 13 Avg accuracy: 0.70284, Avg BCE: 0.60879, F1 Score: 0.02489, ROC_AUC: 0.53580
# Training Results  - Epoch: 13 Precision: 0.61404, Recall: 0.01270
# Validation Results- Epoch: 13 Avg accuracy: 0.73791, Avg BCE: 0.57466, F1 Score: 0.02135, ROC_AUC: 0.51389
# Validation Results- Epoch: 13 Precision: 0.46429, Recall: 0.01092
# Training Results  - Epoch: 14 Avg accuracy: 0.70278, Avg BCE: 0.61056, F1 Score: 0.02799, ROC_AUC: 0.53474
# Training Results  - Epoch: 14 Precision: 0.59398, Recall: 0.01433
# Validation Results- Epoch: 14 Avg accuracy: 0.73813, Avg BCE: 0.57570, F1 Score: 0.02776, ROC_AUC: 0.51310
# Validation Results- Epoch: 14 Precision: 0.48571, Recall: 0.01429
# Training Results  - Epoch: 15 Avg accuracy: 0.70327, Avg BCE: 0.60861, F1 Score: 0.02769, ROC_AUC: 0.54006
# Training Results  - Epoch: 15 Precision: 0.63934, Recall: 0.01415
# Validation Results- Epoch: 15 Avg accuracy: 0.73835, Avg BCE: 0.57456, F1 Score: 0.02299, ROC_AUC: 0.51643
# Validation Results- Epoch: 15 Precision: 0.50000, Recall: 0.01176
# Training Results  - Epoch: 16 Avg accuracy: 0.70365, Avg BCE: 0.60901, F1 Score: 0.02807, ROC_AUC: 0.53913
# Training Results  - Epoch: 16 Precision: 0.67521, Recall: 0.01433
# Validation Results- Epoch: 16 Avg accuracy: 0.73769, Avg BCE: 0.57552, F1 Score: 0.01972, ROC_AUC: 0.51451
# Validation Results- Epoch: 16 Precision: 0.44444, Recall: 0.01008
# Training Results  - Epoch: 17 Avg accuracy: 0.70333, Avg BCE: 0.60983, F1 Score: 0.02770, ROC_AUC: 0.53445
# Training Results  - Epoch: 17 Precision: 0.64463, Recall: 0.01415
# Validation Results- Epoch: 17 Avg accuracy: 0.73791, Avg BCE: 0.57529, F1 Score: 0.02135, ROC_AUC: 0.51390
# Validation Results- Epoch: 17 Precision: 0.46429, Recall: 0.01092
# Training Results  - Epoch: 18 Avg accuracy: 0.70387, Avg BCE: 0.60799, F1 Score: 0.02706, ROC_AUC: 0.54234
# Training Results  - Epoch: 18 Precision: 0.71028, Recall: 0.01379
# Validation Results- Epoch: 18 Avg accuracy: 0.73791, Avg BCE: 0.57482, F1 Score: 0.01812, ROC_AUC: 0.51432
# Validation Results- Epoch: 18 Precision: 0.45833, Recall: 0.00924
# Training Results  - Epoch: 19 Avg accuracy: 0.70392, Avg BCE: 0.61210, F1 Score: 0.02982, ROC_AUC: 0.53737
# Training Results  - Epoch: 19 Precision: 0.68852, Recall: 0.01524
# Validation Results- Epoch: 19 Avg accuracy: 0.73769, Avg BCE: 0.57632, F1 Score: 0.02133, ROC_AUC: 0.51479
# Validation Results- Epoch: 19 Precision: 0.44828, Recall: 0.01092
# Training Results  - Epoch: 20 Avg accuracy: 0.70398, Avg BCE: 0.60797, F1 Score: 0.02707, ROC_AUC: 0.54445
# Training Results  - Epoch: 20 Precision: 0.72381, Recall: 0.01379
# Validation Results- Epoch: 20 Avg accuracy: 0.73813, Avg BCE: 0.57454, F1 Score: 0.01814, ROC_AUC: 0.51671
# Validation Results- Epoch: 20 Precision: 0.47826, Recall: 0.00924
# Training Results  - Epoch: 21 Avg accuracy: 0.70414, Avg BCE: 0.61054, F1 Score: 0.02950, ROC_AUC: 0.53722
# Training Results  - Epoch: 21 Precision: 0.71552, Recall: 0.01506
# Validation Results- Epoch: 21 Avg accuracy: 0.73769, Avg BCE: 0.57559, F1 Score: 0.01811, ROC_AUC: 0.51472
# Validation Results- Epoch: 21 Precision: 0.44000, Recall: 0.00924
# Training Results  - Epoch: 22 Avg accuracy: 0.70387, Avg BCE: 0.60888, F1 Score: 0.02323, ROC_AUC: 0.54616
# Training Results  - Epoch: 22 Precision: 0.76471, Recall: 0.01179
# Validation Results- Epoch: 22 Avg accuracy: 0.73857, Avg BCE: 0.57440, F1 Score: 0.01817, ROC_AUC: 0.51549
# Validation Results- Epoch: 22 Precision: 0.52381, Recall: 0.00924
# Training Results  - Epoch: 23 Avg accuracy: 0.70408, Avg BCE: 0.61061, F1 Score: 0.02603, ROC_AUC: 0.54196
# Training Results  - Epoch: 23 Precision: 0.75258, Recall: 0.01325
# Validation Results- Epoch: 23 Avg accuracy: 0.73813, Avg BCE: 0.57566, F1 Score: 0.01652, ROC_AUC: 0.51484
# Validation Results- Epoch: 23 Precision: 0.47619, Recall: 0.00840
# Training Results  - Epoch: 24 Avg accuracy: 0.70403, Avg BCE: 0.60851, F1 Score: 0.02394, ROC_AUC: 0.54559
# Training Results  - Epoch: 24 Precision: 0.77907, Recall: 0.01216
# Validation Results- Epoch: 24 Avg accuracy: 0.73835, Avg BCE: 0.57513, F1 Score: 0.01490, ROC_AUC: 0.51608
# Validation Results- Epoch: 24 Precision: 0.50000, Recall: 0.00756
# Training Results  - Epoch: 25 Avg accuracy: 0.70398, Avg BCE: 0.61108, F1 Score: 0.02394, ROC_AUC: 0.54851
# Training Results  - Epoch: 25 Precision: 0.77011, Recall: 0.01216
# Validation Results- Epoch: 25 Avg accuracy: 0.73835, Avg BCE: 0.57612, F1 Score: 0.01653, ROC_AUC: 0.51662
# Validation Results- Epoch: 25 Precision: 0.50000, Recall: 0.00840
# Training Results  - Epoch: 26 Avg accuracy: 0.70414, Avg BCE: 0.60978, F1 Score: 0.02430, ROC_AUC: 0.54598
# Training Results  - Epoch: 26 Precision: 0.79070, Recall: 0.01234
# Validation Results- Epoch: 26 Avg accuracy: 0.73857, Avg BCE: 0.57557, F1 Score: 0.01654, ROC_AUC: 0.51618
# Validation Results- Epoch: 26 Precision: 0.52632, Recall: 0.00840
# Training Results  - Epoch: 27 Avg accuracy: 0.70436, Avg BCE: 0.61097, F1 Score: 0.02571, ROC_AUC: 0.54563
# Training Results  - Epoch: 27 Precision: 0.80000, Recall: 0.01306
# Validation Results- Epoch: 27 Avg accuracy: 0.73901, Avg BCE: 0.57598, F1 Score: 0.01982, ROC_AUC: 0.51531
# Validation Results- Epoch: 27 Precision: 0.57143, Recall: 0.01008
# Training Results  - Epoch: 28 Avg accuracy: 0.70425, Avg BCE: 0.61174, F1 Score: 0.02466, ROC_AUC: 0.54897
# Training Results  - Epoch: 28 Precision: 0.80233, Recall: 0.01252
# Validation Results- Epoch: 28 Avg accuracy: 0.73923, Avg BCE: 0.57673, F1 Score: 0.01821, ROC_AUC: 0.51245
# Validation Results- Epoch: 28 Precision: 0.61111, Recall: 0.00924
# Training Results  - Epoch: 29 Avg accuracy: 0.70436, Avg BCE: 0.61195, F1 Score: 0.02536, ROC_AUC: 0.54720
# Training Results  - Epoch: 29 Precision: 0.80682, Recall: 0.01288
# Validation Results- Epoch: 29 Avg accuracy: 0.73879, Avg BCE: 0.57704, F1 Score: 0.01656, ROC_AUC: 0.51283
# Validation Results- Epoch: 29 Precision: 0.55556, Recall: 0.00840
# Training Results  - Epoch: 30 Avg accuracy: 0.70446, Avg BCE: 0.61020, F1 Score: 0.02502, ROC_AUC: 0.55468
# Training Results  - Epoch: 30 Precision: 0.83333, Recall: 0.01270
# Validation Results- Epoch: 30 Avg accuracy: 0.73857, Avg BCE: 0.57635, F1 Score: 0.01491, ROC_AUC: 0.51411
# Validation Results- Epoch: 30 Precision: 0.52941, Recall: 0.00756
# Training Results  - Epoch: 31 Avg accuracy: 0.70457, Avg BCE: 0.60953, F1 Score: 0.02677, ROC_AUC: 0.55341
# Training Results  - Epoch: 31 Precision: 0.81522, Recall: 0.01361
# Validation Results- Epoch: 31 Avg accuracy: 0.73835, Avg BCE: 0.57648, F1 Score: 0.01653, ROC_AUC: 0.51479
# Validation Results- Epoch: 31 Precision: 0.50000, Recall: 0.00840
# Training Results  - Epoch: 32 Avg accuracy: 0.70479, Avg BCE: 0.60779, F1 Score: 0.03060, ROC_AUC: 0.55620
# Training Results  - Epoch: 32 Precision: 0.78182, Recall: 0.01561
# Validation Results- Epoch: 32 Avg accuracy: 0.73791, Avg BCE: 0.57717, F1 Score: 0.01974, ROC_AUC: 0.51321
# Validation Results- Epoch: 32 Precision: 0.46154, Recall: 0.01008
# Training Results  - Epoch: 33 Avg accuracy: 0.70457, Avg BCE: 0.61033, F1 Score: 0.03092, ROC_AUC: 0.55225
# Training Results  - Epoch: 33 Precision: 0.75000, Recall: 0.01579
# Validation Results- Epoch: 33 Avg accuracy: 0.73791, Avg BCE: 0.57769, F1 Score: 0.01812, ROC_AUC: 0.51136
# Validation Results- Epoch: 33 Precision: 0.45833, Recall: 0.00924
# Training Results  - Epoch: 34 Avg accuracy: 0.70484, Avg BCE: 0.60956, F1 Score: 0.02922, ROC_AUC: 0.55734
# Training Results  - Epoch: 34 Precision: 0.81188, Recall: 0.01488
# Validation Results- Epoch: 34 Avg accuracy: 0.73857, Avg BCE: 0.57746, F1 Score: 0.01979, ROC_AUC: 0.51555
# Validation Results- Epoch: 34 Precision: 0.52174, Recall: 0.01008
# Training Results  - Epoch: 35 Avg accuracy: 0.70501, Avg BCE: 0.60617, F1 Score: 0.02820, ROC_AUC: 0.56386
# Training Results  - Epoch: 35 Precision: 0.85870, Recall: 0.01433
# Validation Results- Epoch: 35 Avg accuracy: 0.73791, Avg BCE: 0.57603, F1 Score: 0.01488, ROC_AUC: 0.51936
# Validation Results- Epoch: 35 Precision: 0.45000, Recall: 0.00756
# Training Results  - Epoch: 36 Avg accuracy: 0.70474, Avg BCE: 0.60515, F1 Score: 0.02887, ROC_AUC: 0.56595
# Training Results  - Epoch: 36 Precision: 0.80198, Recall: 0.01470
# Validation Results- Epoch: 36 Avg accuracy: 0.73769, Avg BCE: 0.57684, F1 Score: 0.01649, ROC_AUC: 0.51877
# Validation Results- Epoch: 36 Precision: 0.43478, Recall: 0.00840
# Training Results  - Epoch: 37 Avg accuracy: 0.70479, Avg BCE: 0.60467, F1 Score: 0.03060, ROC_AUC: 0.56637
# Training Results  - Epoch: 37 Precision: 0.78182, Recall: 0.01561
# Validation Results- Epoch: 37 Avg accuracy: 0.73769, Avg BCE: 0.57709, F1 Score: 0.01811, ROC_AUC: 0.51864
# Validation Results- Epoch: 37 Precision: 0.44000, Recall: 0.00924
# Training Results  - Epoch: 38 Avg accuracy: 0.70544, Avg BCE: 0.60348, F1 Score: 0.03342, ROC_AUC: 0.56971
# Training Results  - Epoch: 38 Precision: 0.82456, Recall: 0.01706
# Validation Results- Epoch: 38 Avg accuracy: 0.73747, Avg BCE: 0.57674, F1 Score: 0.01322, ROC_AUC: 0.51921
# Validation Results- Epoch: 38 Precision: 0.40000, Recall: 0.00672
# Training Results  - Epoch: 39 Avg accuracy: 0.70528, Avg BCE: 0.60367, F1 Score: 0.03134, ROC_AUC: 0.57018
# Training Results  - Epoch: 39 Precision: 0.83810, Recall: 0.01597
# Validation Results- Epoch: 39 Avg accuracy: 0.73725, Avg BCE: 0.57730, F1 Score: 0.01321, ROC_AUC: 0.51481
# Validation Results- Epoch: 39 Precision: 0.38095, Recall: 0.00672
# Training Results  - Epoch: 40 Avg accuracy: 0.70539, Avg BCE: 0.60313, F1 Score: 0.03513, ROC_AUC: 0.57222
# Training Results  - Epoch: 40 Precision: 0.79200, Recall: 0.01796
# Validation Results- Epoch: 40 Avg accuracy: 0.73813, Avg BCE: 0.57703, F1 Score: 0.01814, ROC_AUC: 0.51928
# Validation Results- Epoch: 40 Precision: 0.47826, Recall: 0.00924
# Training Results  - Epoch: 41 Avg accuracy: 0.70506, Avg BCE: 0.60412, F1 Score: 0.03372, ROC_AUC: 0.57156
# Training Results  - Epoch: 41 Precision: 0.77236, Recall: 0.01724
# Validation Results- Epoch: 41 Avg accuracy: 0.73769, Avg BCE: 0.57671, F1 Score: 0.01486, ROC_AUC: 0.51677
# Validation Results- Epoch: 41 Precision: 0.42857, Recall: 0.00756
# Training Results  - Epoch: 42 Avg accuracy: 0.70528, Avg BCE: 0.60297, F1 Score: 0.03649, ROC_AUC: 0.57432
# Training Results  - Epoch: 42 Precision: 0.76296, Recall: 0.01869
# Validation Results- Epoch: 42 Avg accuracy: 0.73725, Avg BCE: 0.57734, F1 Score: 0.01646, ROC_AUC: 0.51969
# Validation Results- Epoch: 42 Precision: 0.40000, Recall: 0.00840
# Training Results  - Epoch: 43 Avg accuracy: 0.70566, Avg BCE: 0.60247, F1 Score: 0.04264, ROC_AUC: 0.57617
# Training Results  - Epoch: 43 Precision: 0.73780, Recall: 0.02196
# Validation Results- Epoch: 43 Avg accuracy: 0.73769, Avg BCE: 0.57748, F1 Score: 0.02133, ROC_AUC: 0.52024
# Validation Results- Epoch: 43 Precision: 0.44828, Recall: 0.01092
# Training Results  - Epoch: 44 Avg accuracy: 0.70528, Avg BCE: 0.60128, F1 Score: 0.04192, ROC_AUC: 0.57574
# Training Results  - Epoch: 44 Precision: 0.71257, Recall: 0.02159
# Validation Results- Epoch: 44 Avg accuracy: 0.73703, Avg BCE: 0.57890, F1 Score: 0.01645, ROC_AUC: 0.51664
# Validation Results- Epoch: 44 Precision: 0.38462, Recall: 0.00840
# Training Results  - Epoch: 45 Avg accuracy: 0.70533, Avg BCE: 0.60343, F1 Score: 0.04192, ROC_AUC: 0.56991
# Training Results  - Epoch: 45 Precision: 0.71687, Recall: 0.02159
# Validation Results- Epoch: 45 Avg accuracy: 0.73769, Avg BCE: 0.57743, F1 Score: 0.01811, ROC_AUC: 0.51727
# Validation Results- Epoch: 45 Precision: 0.44000, Recall: 0.00924
# Training Results  - Epoch: 46 Avg accuracy: 0.70544, Avg BCE: 0.60388, F1 Score: 0.04530, ROC_AUC: 0.57160
# Training Results  - Epoch: 46 Precision: 0.70109, Recall: 0.02341
# Validation Results- Epoch: 46 Avg accuracy: 0.73769, Avg BCE: 0.57913, F1 Score: 0.02133, ROC_AUC: 0.51698
# Validation Results- Epoch: 46 Precision: 0.44828, Recall: 0.01092
# Training Results  - Epoch: 47 Avg accuracy: 0.70528, Avg BCE: 0.60190, F1 Score: 0.04427, ROC_AUC: 0.57436
# Training Results  - Epoch: 47 Precision: 0.69613, Recall: 0.02286
# Validation Results- Epoch: 47 Avg accuracy: 0.73725, Avg BCE: 0.57932, F1 Score: 0.01969, ROC_AUC: 0.51479
# Validation Results- Epoch: 47 Precision: 0.41379, Recall: 0.01008
# Training Results  - Epoch: 48 Avg accuracy: 0.70506, Avg BCE: 0.60264, F1 Score: 0.05124, ROC_AUC: 0.57517
# Training Results  - Epoch: 48 Precision: 0.64758, Recall: 0.02667
# Validation Results- Epoch: 48 Avg accuracy: 0.73769, Avg BCE: 0.58035, F1 Score: 0.03087, ROC_AUC: 0.51565
# Validation Results- Epoch: 48 Precision: 0.46341, Recall: 0.01597
# Training Results  - Epoch: 49 Avg accuracy: 0.70501, Avg BCE: 0.60250, F1 Score: 0.05255, ROC_AUC: 0.57596
# Training Results  - Epoch: 49 Precision: 0.63983, Recall: 0.02740
# Validation Results- Epoch: 49 Avg accuracy: 0.73769, Avg BCE: 0.58068, F1 Score: 0.03087, ROC_AUC: 0.51513
# Validation Results- Epoch: 49 Precision: 0.46341, Recall: 0.01597
# Training Results  - Epoch: 50 Avg accuracy: 0.70517, Avg BCE: 0.60160, F1 Score: 0.04893, ROC_AUC: 0.57916
# Training Results  - Epoch: 50 Precision: 0.66351, Recall: 0.02540
# Validation Results- Epoch: 50 Avg accuracy: 0.73835, Avg BCE: 0.58053, F1 Score: 0.03252, ROC_AUC: 0.51551
# Validation Results- Epoch: 50 Precision: 0.50000, Recall: 0.01681
# Training Results  - Epoch: 51 Avg accuracy: 0.70555, Avg BCE: 0.60203, F1 Score: 0.04498, ROC_AUC: 0.57790
# Training Results  - Epoch: 51 Precision: 0.71111, Recall: 0.02323
# Validation Results- Epoch: 51 Avg accuracy: 0.73725, Avg BCE: 0.57956, F1 Score: 0.02129, ROC_AUC: 0.51981
# Validation Results- Epoch: 51 Precision: 0.41935, Recall: 0.01092
# Training Results  - Epoch: 52 Avg accuracy: 0.70533, Avg BCE: 0.60269, F1 Score: 0.05359, ROC_AUC: 0.57842
# Training Results  - Epoch: 52 Precision: 0.65254, Recall: 0.02794
# Validation Results- Epoch: 52 Avg accuracy: 0.73747, Avg BCE: 0.58142, F1 Score: 0.02927, ROC_AUC: 0.51603
# Validation Results- Epoch: 52 Precision: 0.45000, Recall: 0.01513
# Training Results  - Epoch: 53 Avg accuracy: 0.70506, Avg BCE: 0.60289, F1 Score: 0.04625, ROC_AUC: 0.57884
# Training Results  - Epoch: 53 Precision: 0.67005, Recall: 0.02395
# Validation Results- Epoch: 53 Avg accuracy: 0.73747, Avg BCE: 0.58075, F1 Score: 0.02610, ROC_AUC: 0.51685
# Validation Results- Epoch: 53 Precision: 0.44444, Recall: 0.01345
# Training Results  - Epoch: 54 Avg accuracy: 0.70457, Avg BCE: 0.60305, F1 Score: 0.05050, ROC_AUC: 0.57808
# Training Results  - Epoch: 54 Precision: 0.62500, Recall: 0.02631
# Validation Results- Epoch: 54 Avg accuracy: 0.73769, Avg BCE: 0.58121, F1 Score: 0.03401, ROC_AUC: 0.51537
# Validation Results- Epoch: 54 Precision: 0.46667, Recall: 0.01765
# Training Results  - Epoch: 55 Avg accuracy: 0.70506, Avg BCE: 0.60494, F1 Score: 0.05420, ROC_AUC: 0.57486
# Training Results  - Epoch: 55 Precision: 0.63673, Recall: 0.02831
# Validation Results- Epoch: 55 Avg accuracy: 0.73769, Avg BCE: 0.58057, F1 Score: 0.02929, ROC_AUC: 0.51623
# Validation Results- Epoch: 55 Precision: 0.46154, Recall: 0.01513
# Training Results  - Epoch: 56 Avg accuracy: 0.70517, Avg BCE: 0.60182, F1 Score: 0.05521, ROC_AUC: 0.58200
# Training Results  - Epoch: 56 Precision: 0.63855, Recall: 0.02885
# Validation Results- Epoch: 56 Avg accuracy: 0.73725, Avg BCE: 0.58098, F1 Score: 0.03082, ROC_AUC: 0.51561
# Validation Results- Epoch: 56 Precision: 0.44186, Recall: 0.01597
# Training Results  - Epoch: 57 Avg accuracy: 0.70501, Avg BCE: 0.60236, F1 Score: 0.06298, ROC_AUC: 0.58056
# Training Results  - Epoch: 57 Precision: 0.61000, Recall: 0.03321
# Validation Results- Epoch: 57 Avg accuracy: 0.73725, Avg BCE: 0.58242, F1 Score: 0.03239, ROC_AUC: 0.51494
# Validation Results- Epoch: 57 Precision: 0.44444, Recall: 0.01681
# Training Results  - Epoch: 58 Avg accuracy: 0.70528, Avg BCE: 0.60101, F1 Score: 0.06045, ROC_AUC: 0.58247
# Training Results  - Epoch: 58 Precision: 0.62724, Recall: 0.03175
# Validation Results- Epoch: 58 Avg accuracy: 0.73791, Avg BCE: 0.58119, F1 Score: 0.03560, ROC_AUC: 0.51538
# Validation Results- Epoch: 58 Precision: 0.47826, Recall: 0.01849
# Training Results  - Epoch: 59 Avg accuracy: 0.70560, Avg BCE: 0.60085, F1 Score: 0.06343, ROC_AUC: 0.58249
# Training Results  - Epoch: 59 Precision: 0.63230, Recall: 0.03339
# Validation Results- Epoch: 59 Avg accuracy: 0.73725, Avg BCE: 0.58134, F1 Score: 0.03395, ROC_AUC: 0.51555
# Validation Results- Epoch: 59 Precision: 0.44681, Recall: 0.01765
# Training Results  - Epoch: 60 Avg accuracy: 0.70560, Avg BCE: 0.60132, F1 Score: 0.06472, ROC_AUC: 0.58234
# Training Results  - Epoch: 60 Precision: 0.62876, Recall: 0.03411
# Validation Results- Epoch: 60 Avg accuracy: 0.73747, Avg BCE: 0.58177, F1 Score: 0.03710, ROC_AUC: 0.51553
# Validation Results- Epoch: 60 Precision: 0.46000, Recall: 0.01933
# Training Results  - Epoch: 61 Avg accuracy: 0.70549, Avg BCE: 0.60104, F1 Score: 0.06790, ROC_AUC: 0.58380
# Training Results  - Epoch: 61 Precision: 0.61682, Recall: 0.03593
# Validation Results- Epoch: 61 Avg accuracy: 0.73747, Avg BCE: 0.58347, F1 Score: 0.03865, ROC_AUC: 0.51419
# Validation Results- Epoch: 61 Precision: 0.46154, Recall: 0.02017
# Training Results  - Epoch: 62 Avg accuracy: 0.70555, Avg BCE: 0.60011, F1 Score: 0.06663, ROC_AUC: 0.58609
# Training Results  - Epoch: 62 Precision: 0.62179, Recall: 0.03520
# Validation Results- Epoch: 62 Avg accuracy: 0.73725, Avg BCE: 0.58225, F1 Score: 0.04016, ROC_AUC: 0.51672
# Validation Results- Epoch: 62 Precision: 0.45455, Recall: 0.02101
# Training Results  - Epoch: 63 Avg accuracy: 0.70566, Avg BCE: 0.60014, F1 Score: 0.06698, ROC_AUC: 0.58679
# Training Results  - Epoch: 63 Precision: 0.62500, Recall: 0.03538
# Validation Results- Epoch: 63 Avg accuracy: 0.73681, Avg BCE: 0.58239, F1 Score: 0.04163, ROC_AUC: 0.51554
# Validation Results- Epoch: 63 Precision: 0.44068, Recall: 0.02185
# Training Results  - Epoch: 64 Avg accuracy: 0.70560, Avg BCE: 0.59972, F1 Score: 0.06632, ROC_AUC: 0.58732
# Training Results  - Epoch: 64 Precision: 0.62460, Recall: 0.03502
# Validation Results- Epoch: 64 Avg accuracy: 0.73593, Avg BCE: 0.58311, F1 Score: 0.03997, ROC_AUC: 0.51578
# Validation Results- Epoch: 64 Precision: 0.40984, Recall: 0.02101
# Training Results  - Epoch: 65 Avg accuracy: 0.70582, Avg BCE: 0.59976, F1 Score: 0.07148, ROC_AUC: 0.58798
# Training Results  - Epoch: 65 Precision: 0.62018, Recall: 0.03792
# Validation Results- Epoch: 65 Avg accuracy: 0.73439, Avg BCE: 0.58406, F1 Score: 0.04127, ROC_AUC: 0.51633
# Validation Results- Epoch: 65 Precision: 0.37143, Recall: 0.02185
# Training Results  - Epoch: 66 Avg accuracy: 0.70696, Avg BCE: 0.59864, F1 Score: 0.06918, ROC_AUC: 0.58978
# Training Results  - Epoch: 66 Precision: 0.67000, Recall: 0.03647
# Validation Results- Epoch: 66 Avg accuracy: 0.73483, Avg BCE: 0.58407, F1 Score: 0.03365, ROC_AUC: 0.51656
# Validation Results- Epoch: 66 Precision: 0.36207, Recall: 0.01765
# Training Results  - Epoch: 67 Avg accuracy: 0.70690, Avg BCE: 0.59929, F1 Score: 0.09983, ROC_AUC: 0.58893
# Training Results  - Epoch: 67 Precision: 0.60120, Recall: 0.05444
# Validation Results- Epoch: 67 Avg accuracy: 0.72845, Avg BCE: 0.58484, F1 Score: 0.04780, ROC_AUC: 0.51670
# Validation Results- Epoch: 67 Precision: 0.28972, Recall: 0.02605
# Training Results  - Epoch: 68 Avg accuracy: 0.70750, Avg BCE: 0.59795, F1 Score: 0.10568, ROC_AUC: 0.59093
# Training Results  - Epoch: 68 Precision: 0.60646, Recall: 0.05788
# Validation Results- Epoch: 68 Avg accuracy: 0.72735, Avg BCE: 0.58524, F1 Score: 0.04908, ROC_AUC: 0.51657
# Validation Results- Epoch: 68 Precision: 0.28070, Recall: 0.02689
# Training Results  - Epoch: 69 Avg accuracy: 0.70782, Avg BCE: 0.59802, F1 Score: 0.11720, ROC_AUC: 0.59037
# Training Results  - Epoch: 69 Precision: 0.59866, Recall: 0.06496
# Validation Results- Epoch: 69 Avg accuracy: 0.72559, Avg BCE: 0.58526, F1 Score: 0.06726, ROC_AUC: 0.52092
# Validation Results- Epoch: 69 Precision: 0.30405, Recall: 0.03782
# Training Results  - Epoch: 70 Avg accuracy: 0.70771, Avg BCE: 0.59758, F1 Score: 0.08357, ROC_AUC: 0.59461
# Training Results  - Epoch: 70 Precision: 0.65426, Recall: 0.04464
# Validation Results- Epoch: 70 Avg accuracy: 0.73241, Avg BCE: 0.58537, F1 Score: 0.04549, ROC_AUC: 0.51948
# Validation Results- Epoch: 70 Precision: 0.34118, Recall: 0.02437
# Training Results  - Epoch: 71 Avg accuracy: 0.70701, Avg BCE: 0.59829, F1 Score: 0.08121, ROC_AUC: 0.59362
# Training Results  - Epoch: 71 Precision: 0.63733, Recall: 0.04337
# Validation Results- Epoch: 71 Avg accuracy: 0.73307, Avg BCE: 0.58511, F1 Score: 0.04859, ROC_AUC: 0.51852
# Validation Results- Epoch: 71 Precision: 0.36047, Recall: 0.02605
# Training Results  - Epoch: 72 Avg accuracy: 0.70728, Avg BCE: 0.59754, F1 Score: 0.07971, ROC_AUC: 0.59513
# Training Results  - Epoch: 72 Precision: 0.65000, Recall: 0.04246
# Validation Results- Epoch: 72 Avg accuracy: 0.73285, Avg BCE: 0.58537, F1 Score: 0.04706, ROC_AUC: 0.51771
# Validation Results- Epoch: 72 Precision: 0.35294, Recall: 0.02521
# Training Results  - Epoch: 73 Avg accuracy: 0.70793, Avg BCE: 0.59670, F1 Score: 0.08050, ROC_AUC: 0.59669
# Training Results  - Epoch: 73 Precision: 0.67045, Recall: 0.04282
# Validation Results- Epoch: 73 Avg accuracy: 0.73263, Avg BCE: 0.58534, F1 Score: 0.04702, ROC_AUC: 0.51758
# Validation Results- Epoch: 73 Precision: 0.34884, Recall: 0.02521
# Training Results  - Epoch: 74 Avg accuracy: 0.70853, Avg BCE: 0.59637, F1 Score: 0.08875, ROC_AUC: 0.59818
# Training Results  - Epoch: 74 Precision: 0.66667, Recall: 0.04754
# Validation Results- Epoch: 74 Avg accuracy: 0.73197, Avg BCE: 0.58643, F1 Score: 0.04840, ROC_AUC: 0.51723
# Validation Results- Epoch: 74 Precision: 0.34066, Recall: 0.02605
# Training Results  - Epoch: 75 Avg accuracy: 0.70836, Avg BCE: 0.59588, F1 Score: 0.08530, ROC_AUC: 0.59879
# Training Results  - Epoch: 75 Precision: 0.67112, Recall: 0.04555
# Validation Results- Epoch: 75 Avg accuracy: 0.73087, Avg BCE: 0.58637, F1 Score: 0.04225, ROC_AUC: 0.51714
# Validation Results- Epoch: 75 Precision: 0.30682, Recall: 0.02269
# Training Results  - Epoch: 76 Avg accuracy: 0.70880, Avg BCE: 0.59466, F1 Score: 0.08728, ROC_AUC: 0.60214
# Training Results  - Epoch: 76 Precision: 0.67989, Recall: 0.04663
# Validation Results- Epoch: 76 Avg accuracy: 0.73175, Avg BCE: 0.58730, F1 Score: 0.04688, ROC_AUC: 0.51730
# Validation Results- Epoch: 76 Precision: 0.33333, Recall: 0.02521
# Training Results  - Epoch: 77 Avg accuracy: 0.70869, Avg BCE: 0.59379, F1 Score: 0.12754, ROC_AUC: 0.60303
# Training Results  - Epoch: 77 Precision: 0.60276, Recall: 0.07131
# Validation Results- Epoch: 77 Avg accuracy: 0.72405, Avg BCE: 0.58603, F1 Score: 0.07243, ROC_AUC: 0.52532
# Validation Results- Epoch: 77 Precision: 0.30061, Recall: 0.04118
# Training Results  - Epoch: 78 Avg accuracy: 0.70853, Avg BCE: 0.60235, F1 Score: 0.07687, ROC_AUC: 0.59470
# Training Results  - Epoch: 78 Precision: 0.70662, Recall: 0.04065
# Validation Results- Epoch: 78 Avg accuracy: 0.73219, Avg BCE: 0.58945, F1 Score: 0.03639, ROC_AUC: 0.51974
# Validation Results- Epoch: 78 Precision: 0.31081, Recall: 0.01933
# Training Results  - Epoch: 79 Avg accuracy: 0.70782, Avg BCE: 0.59378, F1 Score: 0.10992, ROC_AUC: 0.60184
# Training Results  - Epoch: 79 Precision: 0.60766, Recall: 0.06042
# Validation Results- Epoch: 79 Avg accuracy: 0.72581, Avg BCE: 0.58467, F1 Score: 0.05315, ROC_AUC: 0.52277
# Validation Results- Epoch: 79 Precision: 0.27559, Recall: 0.02941
# Training Results  - Epoch: 80 Avg accuracy: 0.70761, Avg BCE: 0.59455, F1 Score: 0.10660, ROC_AUC: 0.60132
# Training Results  - Epoch: 80 Precision: 0.60755, Recall: 0.05843
# Validation Results- Epoch: 80 Avg accuracy: 0.72383, Avg BCE: 0.58575, F1 Score: 0.04992, ROC_AUC: 0.52194
# Validation Results- Epoch: 80 Precision: 0.25000, Recall: 0.02773
# Training Results  - Epoch: 81 Avg accuracy: 0.70799, Avg BCE: 0.59350, F1 Score: 0.10643, ROC_AUC: 0.60354
# Training Results  - Epoch: 81 Precision: 0.61612, Recall: 0.05825
# Validation Results- Epoch: 81 Avg accuracy: 0.72559, Avg BCE: 0.58485, F1 Score: 0.05455, ROC_AUC: 0.52387
# Validation Results- Epoch: 81 Precision: 0.27692, Recall: 0.03025
# Training Results  - Epoch: 82 Avg accuracy: 0.70679, Avg BCE: 0.59376, F1 Score: 0.15832, ROC_AUC: 0.60335
# Training Results  - Epoch: 82 Precision: 0.55386, Recall: 0.09236
# Validation Results- Epoch: 82 Avg accuracy: 0.71416, Avg BCE: 0.58866, F1 Score: 0.07670, ROC_AUC: 0.52057
# Validation Results- Epoch: 82 Precision: 0.24771, Recall: 0.04538
# Training Results  - Epoch: 83 Avg accuracy: 0.70891, Avg BCE: 0.59125, F1 Score: 0.16374, ROC_AUC: 0.60784
# Training Results  - Epoch: 83 Precision: 0.57549, Recall: 0.09545
# Validation Results- Epoch: 83 Avg accuracy: 0.71240, Avg BCE: 0.58833, F1 Score: 0.07234, ROC_AUC: 0.52246
# Validation Results- Epoch: 83 Precision: 0.23182, Recall: 0.04286
# Training Results  - Epoch: 84 Avg accuracy: 0.71053, Avg BCE: 0.59338, F1 Score: 0.14334, ROC_AUC: 0.59970
# Training Results  - Epoch: 84 Precision: 0.61570, Recall: 0.08111
# Validation Results- Epoch: 84 Avg accuracy: 0.71922, Avg BCE: 0.58741, F1 Score: 0.06720, ROC_AUC: 0.51478
# Validation Results- Epoch: 84 Precision: 0.25698, Recall: 0.03866
# Training Results  - Epoch: 85 Avg accuracy: 0.70804, Avg BCE: 0.59217, F1 Score: 0.16359, ROC_AUC: 0.60542
# Training Results  - Epoch: 85 Precision: 0.56545, Recall: 0.09563
# Validation Results- Epoch: 85 Avg accuracy: 0.71614, Avg BCE: 0.58902, F1 Score: 0.08505, ROC_AUC: 0.51782
# Validation Results- Epoch: 85 Precision: 0.27149, Recall: 0.05042
# Training Results  - Epoch: 86 Avg accuracy: 0.70885, Avg BCE: 0.59295, F1 Score: 0.16940, ROC_AUC: 0.60405
# Training Results  - Epoch: 86 Precision: 0.57143, Recall: 0.09944
# Validation Results- Epoch: 86 Avg accuracy: 0.71658, Avg BCE: 0.58983, F1 Score: 0.09033, ROC_AUC: 0.51618
# Validation Results- Epoch: 86 Precision: 0.28194, Recall: 0.05378
# Training Results  - Epoch: 87 Avg accuracy: 0.70636, Avg BCE: 0.59383, F1 Score: 0.18003, ROC_AUC: 0.60236
# Training Results  - Epoch: 87 Precision: 0.54140, Recall: 0.10797
# Validation Results- Epoch: 87 Avg accuracy: 0.71394, Avg BCE: 0.59080, F1 Score: 0.10214, ROC_AUC: 0.51471
# Validation Results- Epoch: 87 Precision: 0.28571, Recall: 0.06218
# Training Results  - Epoch: 88 Avg accuracy: 0.70939, Avg BCE: 0.59265, F1 Score: 0.15977, ROC_AUC: 0.60492
# Training Results  - Epoch: 88 Precision: 0.58419, Recall: 0.09254
# Validation Results- Epoch: 88 Avg accuracy: 0.72054, Avg BCE: 0.59212, F1 Score: 0.09408, ROC_AUC: 0.51580
# Validation Results- Epoch: 88 Precision: 0.30986, Recall: 0.05546
# Training Results  - Epoch: 89 Avg accuracy: 0.71069, Avg BCE: 0.59047, F1 Score: 0.15103, ROC_AUC: 0.60863
# Training Results  - Epoch: 89 Precision: 0.60976, Recall: 0.08619
# Validation Results- Epoch: 89 Avg accuracy: 0.72164, Avg BCE: 0.58986, F1 Score: 0.07456, ROC_AUC: 0.51946
# Validation Results- Epoch: 89 Precision: 0.28652, Recall: 0.04286
# Training Results  - Epoch: 90 Avg accuracy: 0.70809, Avg BCE: 0.59122, F1 Score: 0.19798, ROC_AUC: 0.60719
# Training Results  - Epoch: 90 Precision: 0.55095, Recall: 0.12067
# Validation Results- Epoch: 90 Avg accuracy: 0.71130, Avg BCE: 0.59115, F1 Score: 0.11344, ROC_AUC: 0.51746
# Validation Results- Epoch: 90 Precision: 0.28866, Recall: 0.07059
# Training Results  - Epoch: 91 Avg accuracy: 0.70983, Avg BCE: 0.58945, F1 Score: 0.15334, ROC_AUC: 0.61061
# Training Results  - Epoch: 91 Precision: 0.59509, Recall: 0.08801
# Validation Results- Epoch: 91 Avg accuracy: 0.72098, Avg BCE: 0.59018, F1 Score: 0.08110, ROC_AUC: 0.52184
# Validation Results- Epoch: 91 Precision: 0.29319, Recall: 0.04706
# Training Results  - Epoch: 92 Avg accuracy: 0.71134, Avg BCE: 0.58997, F1 Score: 0.10814, ROC_AUC: 0.60919
# Training Results  - Epoch: 92 Precision: 0.69762, Recall: 0.05861
# Validation Results- Epoch: 92 Avg accuracy: 0.72999, Avg BCE: 0.59238, F1 Score: 0.05684, ROC_AUC: 0.51614
# Validation Results- Epoch: 92 Precision: 0.33036, Recall: 0.03109
# Training Results  - Epoch: 93 Avg accuracy: 0.70961, Avg BCE: 0.58952, F1 Score: 0.18367, ROC_AUC: 0.61066
# Training Results  - Epoch: 93 Precision: 0.57156, Recall: 0.10942
# Validation Results- Epoch: 93 Avg accuracy: 0.71460, Avg BCE: 0.59048, F1 Score: 0.09610, ROC_AUC: 0.51998
# Validation Results- Epoch: 93 Precision: 0.28049, Recall: 0.05798
# Training Results  - Epoch: 94 Avg accuracy: 0.71162, Avg BCE: 0.58920, F1 Score: 0.13686, ROC_AUC: 0.61037
# Training Results  - Epoch: 94 Precision: 0.64329, Recall: 0.07657
# Validation Results- Epoch: 94 Avg accuracy: 0.72449, Avg BCE: 0.58922, F1 Score: 0.07528, ROC_AUC: 0.52477
# Validation Results- Epoch: 94 Precision: 0.30909, Recall: 0.04286
# Training Results  - Epoch: 95 Avg accuracy: 0.70891, Avg BCE: 0.58844, F1 Score: 0.19118, ROC_AUC: 0.61223
# Training Results  - Epoch: 95 Precision: 0.56095, Recall: 0.11522
# Validation Results- Epoch: 95 Avg accuracy: 0.71372, Avg BCE: 0.59166, F1 Score: 0.09834, ROC_AUC: 0.51991
# Validation Results- Epoch: 95 Precision: 0.27953, Recall: 0.05966
# Training Results  - Epoch: 96 Avg accuracy: 0.71075, Avg BCE: 0.58810, F1 Score: 0.18774, ROC_AUC: 0.61335
# Training Results  - Epoch: 96 Precision: 0.58098, Recall: 0.11196
# Validation Results- Epoch: 96 Avg accuracy: 0.71526, Avg BCE: 0.59113, F1 Score: 0.10381, ROC_AUC: 0.52000
# Validation Results- Epoch: 96 Precision: 0.29412, Recall: 0.06303
# Training Results  - Epoch: 97 Avg accuracy: 0.71075, Avg BCE: 0.58790, F1 Score: 0.18922, ROC_AUC: 0.61336
# Training Results  - Epoch: 97 Precision: 0.58007, Recall: 0.11305
# Validation Results- Epoch: 97 Avg accuracy: 0.71526, Avg BCE: 0.59105, F1 Score: 0.10874, ROC_AUC: 0.52308
# Validation Results- Epoch: 97 Precision: 0.30038, Recall: 0.06639
# Training Results  - Epoch: 98 Avg accuracy: 0.71069, Avg BCE: 0.58708, F1 Score: 0.20677, ROC_AUC: 0.61469
# Training Results  - Epoch: 98 Precision: 0.57002, Recall: 0.12629
# Validation Results- Epoch: 98 Avg accuracy: 0.71020, Avg BCE: 0.59279, F1 Score: 0.11066, ROC_AUC: 0.51978
# Validation Results- Epoch: 98 Precision: 0.28082, Recall: 0.06891
# Training Results  - Epoch: 99 Avg accuracy: 0.70983, Avg BCE: 0.58711, F1 Score: 0.21143, ROC_AUC: 0.61575
# Training Results  - Epoch: 99 Precision: 0.56050, Recall: 0.13028
# Validation Results- Epoch: 99 Avg accuracy: 0.70910, Avg BCE: 0.59287, F1 Score: 0.11386, ROC_AUC: 0.52194
# Validation Results- Epoch: 99 Precision: 0.28053, Recall: 0.07143
# Training Results  - Epoch: 100 Avg accuracy: 0.70934, Avg BCE: 0.58747, F1 Score: 0.21986, ROC_AUC: 0.61613
# Training Results  - Epoch: 100 Precision: 0.55344, Recall: 0.13718
# Validation Results- Epoch: 100 Avg accuracy: 0.71042, Avg BCE: 0.59359, F1 Score: 0.12724, ROC_AUC: 0.52240
# Validation Results- Epoch: 100 Precision: 0.30094, Recall: 0.08067

# %%
evaluator.state.metrics
# Out:
# {'accuracy': 0.7104221635883905,
#  'bce': 0.5935904205946306,
#  'f1_score': 0.12723658051689862,
#  'roc_auc': 0.5224025405278252,
#  'precision': 0.30094043887147337,
#  'recall': 0.08067226890756303}

# %%
binary_y_test.mean()
# Out:
# marketHigh_-20    0.254617
# marketLow_-20     0.268690
# dtype: float64
